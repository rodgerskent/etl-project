# %%
# Note that the initial license file from Colorado was too big to load into git hub.
# I ran earlier notebooks to analyze the dataset and determine the best way to reduce it.
# The original 1.2 million line professional license file was reduced to two files a) anesthesia and b) registereed nurse
# This notebook picks-up with a smaller license_anesthesia file that relates just to the non-physician anesthesia clinicians
# and a smaller license_regnurse file that relates to the underlying RN license file that supports practicing as a CRNA

# %% [markdown]
# # Rodgers Secondary Extract & Transform Workbook

# %%
# Initial Extract & Transform Dependencies
import pandas as pd
import time

# Secondardy PGAdmin Extract Dependencies
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float 
from config import passcode

# %%
# Import the file of non-physician anesthesia clinicians
anesthesia=pd.read_csv('license_anesthesia.csv')
anesthesia.head()
# Out:
#    lastName firstName middleName suffix  entityName          city state  \
# 0   Charles     James     Robert    NaN         NaN        Golden    CO
# 1     Stagg   Russell      Adair    NaN         NaN        Meeker    CO
# 2   Sampier    Nicole   Louise A    NaN         NaN         Tampa    FL
# 3  Trouskie   William    Leonard     JR         NaN         Rifle    CO
# 4     Penix   Patrick  Alexander    NaN         NaN  Fort Collins    CO
#
#   mailZipCode licensePrefix subCategory  ...  licenseStatusDescription  \
# 0       80401           APN        CRNA  ...                    Active
# 1       81641         C-APN      C-CRNA  ...                   Expired
# 2       33602           APN        CRNA  ...                    Active
# 3       81650           APN        CRNA  ...                    Active
# 4       80526           APN        CRNA  ...                    Active
#
#   specialty title                           degrees caseNumber programAction  \
# 0       NaN   NaN  ~Bachelors of Science in Nursing        NaN           NaN
# 1       NaN   NaN      ~Assoc of Science in Nursing        NaN           NaN
# 2       NaN   NaN  ~Bachelors of Science in Nursing        NaN           NaN
# 3       NaN   NaN  ~Bachelors of Science in Nursing        NaN           NaN
# 4       NaN   NaN  ~Bachelors of Science in Nursing        NaN           NaN
#
#    disciplineEffectiveDate disciplineCompleteDate  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
#
#                                  linkToVerifyLicense  \
# 0  https://www.colorado.gov/dora/licensing/Lookup...
# 1  https://www.colorado.gov/dora/licensing/Lookup...
# 2  https://www.colorado.gov/dora/licensing/Lookup...
# 3  https://www.colorado.gov/dora/licensing/Lookup...
# 4  https://www.colorado.gov/dora/licensing/Lookup...
#
#                          linkToViewHealthcareProfile
# 0                                                NaN
# 1  https://www.colorado.gov/dora/licensing/Snapsh...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 24 columns]

# %%
#anesthesia.info()

# %%
# Create a last plus first name matching element to merge dataframes
anesthesia['matchName'] = anesthesia['lastName'] + anesthesia['firstName']
anesthesia.head()
# Out:
#    lastName firstName middleName suffix  entityName          city state  \
# 0   Charles     James     Robert    NaN         NaN        Golden    CO
# 1     Stagg   Russell      Adair    NaN         NaN        Meeker    CO
# 2   Sampier    Nicole   Louise A    NaN         NaN         Tampa    FL
# 3  Trouskie   William    Leonard     JR         NaN         Rifle    CO
# 4     Penix   Patrick  Alexander    NaN         NaN  Fort Collins    CO
#
#   mailZipCode licensePrefix subCategory  ...  specialty title  \
# 0       80401           APN        CRNA  ...        NaN   NaN
# 1       81641         C-APN      C-CRNA  ...        NaN   NaN
# 2       33602           APN        CRNA  ...        NaN   NaN
# 3       81650           APN        CRNA  ...        NaN   NaN
# 4       80526           APN        CRNA  ...        NaN   NaN
#
#                             degrees caseNumber programAction  \
# 0  ~Bachelors of Science in Nursing        NaN           NaN
# 1      ~Assoc of Science in Nursing        NaN           NaN
# 2  ~Bachelors of Science in Nursing        NaN           NaN
# 3  ~Bachelors of Science in Nursing        NaN           NaN
# 4  ~Bachelors of Science in Nursing        NaN           NaN
#
#   disciplineEffectiveDate  disciplineCompleteDate  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#                                  linkToVerifyLicense  \
# 0  https://www.colorado.gov/dora/licensing/Lookup...
# 1  https://www.colorado.gov/dora/licensing/Lookup...
# 2  https://www.colorado.gov/dora/licensing/Lookup...
# 3  https://www.colorado.gov/dora/licensing/Lookup...
# 4  https://www.colorado.gov/dora/licensing/Lookup...
#
#                          linkToViewHealthcareProfile        matchName
# 0                                                NaN     CharlesJames
# 1  https://www.colorado.gov/dora/licensing/Snapsh...     StaggRussell
# 2                                                NaN    SampierNicole
# 3                                                NaN  TrouskieWilliam
# 4                                                NaN     PenixPatrick
#
# [5 rows x 25 columns]

# %%
# Remove excess columns
del anesthesia["suffix"]
del anesthesia["entityName"]
del anesthesia["specialty"]
del anesthesia["title"]
del anesthesia["degrees"]
del anesthesia["linkToVerifyLicense"]
del anesthesia["linkToViewHealthcareProfile"]
anesthesia.head()
# Out:
#    lastName firstName middleName          city state mailZipCode  \
# 0   Charles     James     Robert        Golden    CO       80401
# 1     Stagg   Russell      Adair        Meeker    CO       81641
# 2   Sampier    Nicole   Louise A         Tampa    FL       33602
# 3  Trouskie   William    Leonard         Rifle    CO       81650
# 4     Penix   Patrick  Alexander  Fort Collins    CO       80526
#
#   licensePrefix subCategory  licenseNumber   licenseFirstIssueDate  \
# 0           APN        CRNA           3656  02/15/2002 12:00:00 AM
# 1         C-APN      C-CRNA            211  06/18/2014 12:00:00 AM
# 2           APN        CRNA         994392  01/03/2019 12:00:00 AM
# 3           APN        CRNA          15066  03/02/2010 12:00:00 AM
# 4           APN        CRNA         995315  01/27/2020 12:00:00 AM
#
#    licenseLastRenewedDate   licenseExpirationDate licenseStatusDescription  \
# 0  10/01/2019 12:00:00 AM  09/30/2021 12:00:00 AM                   Active
# 1  06/18/2014 12:00:00 AM  11/05/2014 12:00:00 AM                  Expired
# 2  10/01/2019 12:00:00 AM  09/30/2021 12:00:00 AM                   Active
# 3  10/01/2020 12:00:00 AM  09/30/2022 12:00:00 AM                   Active
# 4  10/01/2020 12:00:00 AM  09/30/2022 12:00:00 AM                   Active
#
#   caseNumber programAction disciplineEffectiveDate disciplineCompleteDate  \
# 0        NaN           NaN                     NaN                    NaN
# 1        NaN           NaN                     NaN                    NaN
# 2        NaN           NaN                     NaN                    NaN
# 3        NaN           NaN                     NaN                    NaN
# 4        NaN           NaN                     NaN                    NaN
#
#          matchName
# 0     CharlesJames
# 1     StaggRussell
# 2    SampierNicole
# 3  TrouskieWilliam
# 4     PenixPatrick

# %%
# Rename state to st because it looks like postgres is going to choke on it 
anesthesia = anesthesia.rename(columns={"state" : "st"})

# %%
anesthesia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2448 entries, 0 to 2447
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lastName                  2448 non-null   object
#  1   firstName                 2448 non-null   object
#  2   middleName                2200 non-null   object
#  3   city                      2448 non-null   object
#  4   st                        2448 non-null   object
#  5   mailZipCode               2447 non-null   object
#  6   licensePrefix             2448 non-null   object
#  7   subCategory               2310 non-null   object
#  8   licenseNumber             2448 non-null   int64
#  9   licenseFirstIssueDate     2448 non-null   object
#  10  licenseLastRenewedDate    2447 non-null   object
#  11  licenseExpirationDate     2448 non-null   object
#  12  licenseStatusDescription  2448 non-null   object
#  13  caseNumber                7 non-null      object
#  14  programAction             7 non-null      object
#  15  disciplineEffectiveDate   7 non-null      object
#  16  disciplineCompleteDate    1 non-null      object
#  17  matchName                 2448 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 344.4+ KB

# %%
# Stage cleaned anesthesia file for database build
anesthesia.to_csv("loadAnesthesiaLicense.csv", index=False, header=True)

# %%
# Confirm that last name on its own will not support a matching process
# anesthesia['lastName'].value_counts()

# %%
# Confirm that last name first name combo on its own will support a matching process or build exception process
# anesthesia['matchName'].value_counts()

# %%
# Import the file with the registered nurse information required to validate underlying licenses
nurse=pd.read_csv('license_regnurse.csv')
nurse.head()
# Out:
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,4,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    lastName firstName middleName suffix entityName              city state  \
# 0  Saracino      Jodi        Kay    NaN        NaN            Arvada    CO
# 1      Neal    Carmen    Darlene    NaN        NaN          Longview    TX
# 2  Freeland    Judith         A.    NaN        NaN            BAILEY    CO
# 3     Healy     Julie          E    NaN        NaN  Colorado Springs    CO
# 4   Englade     Keith     Steven    NaN        NaN            Aurora    CO
#
#   mailZipCode licensePrefix  subCategory  ...  licenseStatusDescription  \
# 0       80004            RN          NaN  ...                    Active
# 1       75608            RN          NaN  ...                   Expired
# 2       80421            RN          NaN  ...                   Expired
# 3       80920            RN          NaN  ...                    Active
# 4       80013            RN          NaN  ...                    Active
#
#   specialty title                           degrees caseNumber  programAction  \
# 0       NaN   NaN  ~Bachelors of Science in Nursing        NaN            NaN
# 1       NaN   NaN      ~Assoc of Science in Nursing        NaN            NaN
# 2       NaN   NaN                               NaN        NaN            NaN
# 3       NaN   NaN      ~Associate Degree in Nursing        NaN            NaN
# 4       NaN   NaN  ~Bachelors of Science in Nursing        NaN            NaN
#
#    disciplineEffectiveDate disciplineCompleteDate  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
#
#                                  linkToVerifyLicense  \
# 0  https://www.colorado.gov/dora/licensing/Lookup...
# 1  https://www.colorado.gov/dora/licensing/Lookup...
# 2  https://www.colorado.gov/dora/licensing/Lookup...
# 3  https://www.colorado.gov/dora/licensing/Lookup...
# 4  https://www.colorado.gov/dora/licensing/Lookup...
#
#                          linkToViewHealthcareProfile
# 0  https://www.colorado.gov/dora/licensing/Snapsh...
# 1  https://www.colorado.gov/dora/licensing/Snapsh...
# 2                                                NaN
# 3  https://www.colorado.gov/dora/licensing/Snapsh...
# 4  https://www.colorado.gov/dora/licensing/Snapsh...
#
# [5 rows x 24 columns]

# %%
# Create a last plus first name matching element to merge dataframes
nurse['matchName'] = nurse['lastName'] + nurse['firstName']
nurse.head()
# Out:
#    lastName firstName middleName suffix entityName              city state  \
# 0  Saracino      Jodi        Kay    NaN        NaN            Arvada    CO
# 1      Neal    Carmen    Darlene    NaN        NaN          Longview    TX
# 2  Freeland    Judith         A.    NaN        NaN            BAILEY    CO
# 3     Healy     Julie          E    NaN        NaN  Colorado Springs    CO
# 4   Englade     Keith     Steven    NaN        NaN            Aurora    CO
#
#   mailZipCode licensePrefix  subCategory  ...  specialty title  \
# 0       80004            RN          NaN  ...        NaN   NaN
# 1       75608            RN          NaN  ...        NaN   NaN
# 2       80421            RN          NaN  ...        NaN   NaN
# 3       80920            RN          NaN  ...        NaN   NaN
# 4       80013            RN          NaN  ...        NaN   NaN
#
#                             degrees caseNumber programAction  \
# 0  ~Bachelors of Science in Nursing        NaN           NaN
# 1      ~Assoc of Science in Nursing        NaN           NaN
# 2                               NaN        NaN           NaN
# 3      ~Associate Degree in Nursing        NaN           NaN
# 4  ~Bachelors of Science in Nursing        NaN           NaN
#
#    disciplineEffectiveDate  disciplineCompleteDate  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
#                                  linkToVerifyLicense  \
# 0  https://www.colorado.gov/dora/licensing/Lookup...
# 1  https://www.colorado.gov/dora/licensing/Lookup...
# 2  https://www.colorado.gov/dora/licensing/Lookup...
# 3  https://www.colorado.gov/dora/licensing/Lookup...
# 4  https://www.colorado.gov/dora/licensing/Lookup...
#
#                          linkToViewHealthcareProfile       matchName
# 0  https://www.colorado.gov/dora/licensing/Snapsh...    SaracinoJodi
# 1  https://www.colorado.gov/dora/licensing/Snapsh...      NealCarmen
# 2                                                NaN  FreelandJudith
# 3  https://www.colorado.gov/dora/licensing/Snapsh...      HealyJulie
# 4  https://www.colorado.gov/dora/licensing/Snapsh...    EngladeKeith
#
# [5 rows x 25 columns]

# %%
#nurse.info()

# %%
# Remove unneeded columns
del nurse["suffix"]
del nurse["entityName"]
del nurse["subCategory"]
del nurse["specialty"]
del nurse["title"]
del nurse["licenseFirstIssueDate"]
del nurse["licenseLastRenewedDate"]
del nurse["degrees"]
del nurse["caseNumber"]
del nurse["programAction"]
del nurse["disciplineEffectiveDate"]
del nurse["disciplineCompleteDate"]
del nurse["linkToVerifyLicense"]
del nurse["linkToViewHealthcareProfile"]
nurse.head()
# Out:
#    lastName firstName middleName              city state mailZipCode  \
# 0  Saracino      Jodi        Kay            Arvada    CO       80004
# 1      Neal    Carmen    Darlene          Longview    TX       75608
# 2  Freeland    Judith         A.            BAILEY    CO       80421
# 3     Healy     Julie          E  Colorado Springs    CO       80920
# 4   Englade     Keith     Steven            Aurora    CO       80013
#
#   licensePrefix  licenseNumber   licenseExpirationDate  \
# 0            RN       103136.0  09/30/2021 12:00:00 AM
# 1            RN       181576.0  09/30/2015 12:00:00 AM
# 2            RN        92692.0  09/30/2005 12:00:00 AM
# 3            RN       130994.0  09/30/2021 12:00:00 AM
# 4            RN       205425.0  09/30/2022 12:00:00 AM
#
#   licenseStatusDescription       matchName
# 0                   Active    SaracinoJodi
# 1                  Expired      NealCarmen
# 2                  Expired  FreelandJudith
# 3                   Active      HealyJulie
# 4                   Active    EngladeKeith

# %%
# Rename state to st because it looks like postgres is going to choke on it 
nurse = nurse.rename(columns={"state" : "st"})

# %%
nurse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196995 entries, 0 to 196994
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   lastName                  196994 non-null  object
#  1   firstName                 196993 non-null  object
#  2   middleName                180778 non-null  object
#  3   city                      196194 non-null  object
#  4   st                        194724 non-null  object
#  5   mailZipCode               195656 non-null  object
#  6   licensePrefix             196995 non-null  object
#  7   licenseNumber             196991 non-null  float64
#  8   licenseExpirationDate     196994 non-null  object
#  9   licenseStatusDescription  196995 non-null  object
#  10  matchName                 196993 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 16.5+ MB

# %%
# Stage cleaned registered nurse license file for database build
nurse.to_csv("loadNurseLicense.csv", index=False, header=True)

# %%
#Import the employee roster (a random subset of public licensees used as fictitious roster in lieu of actual employee roster)
employee=pd.read_csv('employee_roster.csv')
employee.head()
# Out:
#    lastName firstName middleName  employeeNum          city state  \
# 0  Ackerman    Serena      Maija           97  Mount Shasta    CA
# 1     Adams      Chad          R         1049     Lexington    KY
# 2     Ahern   Caitlin      Moira         1260     Englewood    CO
# 3    Balyer       Ean        NaN          859       Madison    WI
# 4  Barfield  Benjamin      James           67        Denver    CO
#
#    mailZipCode title         hireDate  projectIndicator
# 0        96067  CRNA   3/16/2009 0:00                 1
# 1        40514  CRNA    7/2/2018 0:00                 1
# 2        80112  CRNA  10/23/2020 0:00                 2
# 3        53703    AA   3/20/2019 0:00                 1
# 4        80238    AA    6/5/2013 0:00                 1

# %%
# Create a last plus first name matching element to merge dataframes
employee['matchName'] = employee['lastName'] + employee['firstName']
employee.head()
# Out:
#    lastName firstName middleName  employeeNum          city state  \
# 0  Ackerman    Serena      Maija           97  Mount Shasta    CA
# 1     Adams      Chad          R         1049     Lexington    KY
# 2     Ahern   Caitlin      Moira         1260     Englewood    CO
# 3    Balyer       Ean        NaN          859       Madison    WI
# 4  Barfield  Benjamin      James           67        Denver    CO
#
#    mailZipCode title         hireDate  projectIndicator         matchName
# 0        96067  CRNA   3/16/2009 0:00                 1    AckermanSerena
# 1        40514  CRNA    7/2/2018 0:00                 1         AdamsChad
# 2        80112  CRNA  10/23/2020 0:00                 2      AhernCaitlin
# 3        53703    AA   3/20/2019 0:00                 1         BalyerEan
# 4        80238    AA    6/5/2013 0:00                 1  BarfieldBenjamin

# %%
# Remove excess columns
del employee["projectIndicator"]
del employee["city"]
del employee["state"]
del employee["mailZipCode"]
employee.head()
# Out:
#    lastName firstName middleName  employeeNum title         hireDate  \
# 0  Ackerman    Serena      Maija           97  CRNA   3/16/2009 0:00
# 1     Adams      Chad          R         1049  CRNA    7/2/2018 0:00
# 2     Ahern   Caitlin      Moira         1260  CRNA  10/23/2020 0:00
# 3    Balyer       Ean        NaN          859    AA   3/20/2019 0:00
# 4  Barfield  Benjamin      James           67    AA    6/5/2013 0:00
#
#           matchName
# 0    AckermanSerena
# 1         AdamsChad
# 2      AhernCaitlin
# 3         BalyerEan
# 4  BarfieldBenjamin

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   lastName     79 non-null     object
#  1   firstName    79 non-null     object
#  2   middleName   67 non-null     object
#  3   employeeNum  79 non-null     int64
#  4   title        79 non-null     object
#  5   hireDate     79 non-null     object
#  6   matchName    79 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 4.4+ KB

# %%
# Stage cleaned employee roster file for database build
employee.to_csv("loadEmployeeRoster.csv", index=False, header=True)

# %%
# Compliance Reporting Section

# %% [markdown]
# # CSV to Pandas -  Anesthesia License Management Section

# %%
# One - Merge the employee and anesthesia license status dataframes using a left join
astatus = pd.merge(employee, anesthesia, on="matchName", how="left")
astatus.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 3      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 4     Balyer         Ean          NaN          859    AA   3/20/2019 0:00
#
#         matchName lastName_y firstName_y middleName_y  ... subCategory  \
# 0  AckermanSerena   Ackerman      Serena        Maija  ...        CRNA
# 1       AdamsChad      Adams        Chad            R  ...      C-CRNA
# 2    AhernCaitlin      Ahern     Caitlin        Moira  ...        CRNA
# 3    AhernCaitlin      Ahern     Caitlin        Moira  ...      C-CRNA
# 4       BalyerEan     Balyer         Ean          NaN  ...         NaN
#
#   licenseNumber   licenseFirstIssueDate  licenseLastRenewedDate  \
# 0          6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1          1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 2        995962  10/23/2020 12:00:00 AM  10/23/2020 12:00:00 AM
# 3          2009  04/08/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 4           109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
#
#     licenseExpirationDate  licenseStatusDescription caseNumber programAction  \
# 0  09/30/2021 12:00:00 AM                    Active        NaN           NaN
# 1  09/30/2022 12:00:00 AM                    Active        NaN           NaN
# 2  09/30/2021 12:00:00 AM                    Active        NaN           NaN
# 3  10/23/2020 12:00:00 AM                   Expired        NaN           NaN
# 4  01/31/2022 12:00:00 AM                    Active        NaN           NaN
#
#   disciplineEffectiveDate disciplineCompleteDate
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
#
# [5 rows x 24 columns]

# %%
astatus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lastName_x                101 non-null    object
#  1   firstName_x               101 non-null    object
#  2   middleName_x              84 non-null     object
#  3   employeeNum               101 non-null    int64
#  4   title                     101 non-null    object
#  5   hireDate                  101 non-null    object
#  6   matchName                 101 non-null    object
#  7   lastName_y                101 non-null    object
#  8   firstName_y               101 non-null    object
#  9   middleName_y              84 non-null     object
#  10  city                      101 non-null    object
#  11  st                        101 non-null    object
#  12  mailZipCode               101 non-null    object
#  13  licensePrefix             101 non-null    object
#  14  subCategory               94 non-null     object
#  15  licenseNumber             101 non-null    int64
#  16  licenseFirstIssueDate     101 non-null    object
#  17  licenseLastRenewedDate    101 non-null    object
#  18  licenseExpirationDate     101 non-null    object
#  19  licenseStatusDescription  101 non-null    object
#  20  caseNumber                0 non-null      object
#  21  programAction             0 non-null      object
#  22  disciplineEffectiveDate   0 non-null      object
#  23  disciplineCompleteDate    0 non-null      object
# dtypes: int64(2), object(22)
# memory usage: 19.7+ KB

# %%
# TWo - Sort by matchName then licenseStatus, "Active" first
astatus.sort_values(by=['matchName', 'licenseStatusDescription'], inplace=True)
astatus.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 3      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 4     Balyer         Ean          NaN          859    AA   3/20/2019 0:00
#
#         matchName lastName_y firstName_y middleName_y  ... subCategory  \
# 0  AckermanSerena   Ackerman      Serena        Maija  ...        CRNA
# 1       AdamsChad      Adams        Chad            R  ...      C-CRNA
# 2    AhernCaitlin      Ahern     Caitlin        Moira  ...        CRNA
# 3    AhernCaitlin      Ahern     Caitlin        Moira  ...      C-CRNA
# 4       BalyerEan     Balyer         Ean          NaN  ...         NaN
#
#   licenseNumber   licenseFirstIssueDate  licenseLastRenewedDate  \
# 0          6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1          1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 2        995962  10/23/2020 12:00:00 AM  10/23/2020 12:00:00 AM
# 3          2009  04/08/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 4           109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
#
#     licenseExpirationDate  licenseStatusDescription caseNumber programAction  \
# 0  09/30/2021 12:00:00 AM                    Active        NaN           NaN
# 1  09/30/2022 12:00:00 AM                    Active        NaN           NaN
# 2  09/30/2021 12:00:00 AM                    Active        NaN           NaN
# 3  10/23/2020 12:00:00 AM                   Expired        NaN           NaN
# 4  01/31/2022 12:00:00 AM                    Active        NaN           NaN
#
#   disciplineEffectiveDate disciplineCompleteDate
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
#
# [5 rows x 24 columns]

# %%
# Three Remove duplicates leaving the active license in the compliance reporting process if it exists
astatus.drop_duplicates(subset ="matchName", keep = False, inplace = True) 
#astatus.to_csv("report_anesthesia_compliance.csv", index=False, header=True)
astatus.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 4     Balyer         Ean          NaN          859    AA   3/20/2019 0:00
# 5   Barfield    Benjamin        James           67    AA    6/5/2013 0:00
# 8  Boudreaux       David      Michael          551  CRNA  10/12/2010 0:00
#
#           matchName lastName_y firstName_y middleName_y  ... subCategory  \
# 0    AckermanSerena   Ackerman      Serena        Maija  ...        CRNA
# 1         AdamsChad      Adams        Chad            R  ...      C-CRNA
# 4         BalyerEan     Balyer         Ean          NaN  ...         NaN
# 5  BarfieldBenjamin   Barfield    Benjamin        James  ...         NaN
# 8    BoudreauxDavid  Boudreaux       David      Michael  ...        CRNA
#
#   licenseNumber   licenseFirstIssueDate  licenseLastRenewedDate  \
# 0          6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1          1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 4           109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# 5            10  06/05/2013 12:00:00 AM  02/01/2020 12:00:00 AM
# 8        100010  10/12/2010 12:00:00 AM  10/01/2020 12:00:00 AM
#
#     licenseExpirationDate  licenseStatusDescription caseNumber programAction  \
# 0  09/30/2021 12:00:00 AM                    Active        NaN           NaN
# 1  09/30/2022 12:00:00 AM                    Active        NaN           NaN
# 4  01/31/2022 12:00:00 AM                    Active        NaN           NaN
# 5  01/31/2022 12:00:00 AM                    Active        NaN           NaN
# 8  09/30/2022 12:00:00 AM                    Active        NaN           NaN
#
#   disciplineEffectiveDate disciplineCompleteDate
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 4                     NaN                    NaN
# 5                     NaN                    NaN
# 8                     NaN                    NaN
#
# [5 rows x 24 columns]

# %%
astatus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 100
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lastName_x                60 non-null     object
#  1   firstName_x               60 non-null     object
#  2   middleName_x              53 non-null     object
#  3   employeeNum               60 non-null     int64
#  4   title                     60 non-null     object
#  5   hireDate                  60 non-null     object
#  6   matchName                 60 non-null     object
#  7   lastName_y                60 non-null     object
#  8   firstName_y               60 non-null     object
#  9   middleName_y              53 non-null     object
#  10  city                      60 non-null     object
#  11  st                        60 non-null     object
#  12  mailZipCode               60 non-null     object
#  13  licensePrefix             60 non-null     object
#  14  subCategory               53 non-null     object
#  15  licenseNumber             60 non-null     int64
#  16  licenseFirstIssueDate     60 non-null     object
#  17  licenseLastRenewedDate    60 non-null     object
#  18  licenseExpirationDate     60 non-null     object
#  19  licenseStatusDescription  60 non-null     object
#  20  caseNumber                0 non-null      object
#  21  programAction             0 non-null      object
#  22  disciplineEffectiveDate   0 non-null      object
#  23  disciplineCompleteDate    0 non-null      object
# dtypes: int64(2), object(22)
# memory usage: 11.7+ KB

# %%
# Four Produce a red flag report of out of compliance anesthesia clinicians
redflag = astatus[(astatus["licenseStatusDescription"] == "Expired")]
#redflag.to_csv("report_anesthesia_redflag.csv", index=False, header=True)
redflag.head()
# Out:
#    lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 81      Smith   Catherine           Vu         1255  CRNA  11/24/2020 0:00
#
#          matchName lastName_y firstName_y middleName_y  ... subCategory  \
# 81  SmithCatherine      Smith   Catherine           Vu  ...      C-CRNA
#
#    licenseNumber   licenseFirstIssueDate  licenseLastRenewedDate  \
# 81          1082  05/21/2018 12:00:00 AM  10/01/2020 12:00:00 AM
#
#      licenseExpirationDate  licenseStatusDescription caseNumber programAction  \
# 81  11/24/2020 12:00:00 AM                   Expired        NaN           NaN
#
#    disciplineEffectiveDate disciplineCompleteDate
# 81                     NaN                    NaN
#
# [1 rows x 24 columns]

# %% [markdown]
# # CSV to Pandas -  Registered Nurse Sub-License Management Section

# %%
# One - Merge the employee and registered nurse license status dataframes using a left join
rn_status = pd.merge(employee, nurse, on="matchName", how="left")
rn_status.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 3     Balyer         Ean          NaN          859    AA   3/20/2019 0:00
# 4   Barfield    Benjamin        James           67    AA    6/5/2013 0:00
#
#           matchName lastName_y firstName_y middleName_y          city   st  \
# 0    AckermanSerena   Ackerman      Serena        Maija  Mount Shasta   CA
# 1         AdamsChad      Adams        Chad            A      Longmont   CO
# 2      AhernCaitlin      Ahern     Caitlin        Moira     Englewood   CO
# 3         BalyerEan        NaN         NaN          NaN           NaN  NaN
# 4  BarfieldBenjamin        NaN         NaN          NaN           NaN  NaN
#
#   mailZipCode licensePrefix  licenseNumber   licenseExpirationDate  \
# 0       96067            RN       181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN       167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN      1622686.0  09/30/2021 12:00:00 AM
# 3         NaN           NaN            NaN                     NaN
# 4         NaN           NaN            NaN                     NaN
#
#   licenseStatusDescription
# 0                   Active
# 1                   Active
# 2                   Active
# 3                      NaN
# 4                      NaN

# %%
# Two - Sort by matchName then licenseStatus, "Active" first
rn_status.sort_values(by=['matchName', 'licenseStatusDescription'], inplace=True)
rn_status.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 3     Balyer         Ean          NaN          859    AA   3/20/2019 0:00
# 4   Barfield    Benjamin        James           67    AA    6/5/2013 0:00
#
#           matchName lastName_y firstName_y middleName_y          city   st  \
# 0    AckermanSerena   Ackerman      Serena        Maija  Mount Shasta   CA
# 1         AdamsChad      Adams        Chad            A      Longmont   CO
# 2      AhernCaitlin      Ahern     Caitlin        Moira     Englewood   CO
# 3         BalyerEan        NaN         NaN          NaN           NaN  NaN
# 4  BarfieldBenjamin        NaN         NaN          NaN           NaN  NaN
#
#   mailZipCode licensePrefix  licenseNumber   licenseExpirationDate  \
# 0       96067            RN       181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN       167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN      1622686.0  09/30/2021 12:00:00 AM
# 3         NaN           NaN            NaN                     NaN
# 4         NaN           NaN            NaN                     NaN
#
#   licenseStatusDescription
# 0                   Active
# 1                   Active
# 2                   Active
# 3                      NaN
# 4                      NaN

# %%
# Three - Remove duplicates leaving the "Active" status if true
rn_status.drop_duplicates(subset ="matchName", keep = False, inplace = True) 
rn_status.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 3     Balyer         Ean          NaN          859    AA   3/20/2019 0:00
# 4   Barfield    Benjamin        James           67    AA    6/5/2013 0:00
#
#           matchName lastName_y firstName_y middleName_y          city   st  \
# 0    AckermanSerena   Ackerman      Serena        Maija  Mount Shasta   CA
# 1         AdamsChad      Adams        Chad            A      Longmont   CO
# 2      AhernCaitlin      Ahern     Caitlin        Moira     Englewood   CO
# 3         BalyerEan        NaN         NaN          NaN           NaN  NaN
# 4  BarfieldBenjamin        NaN         NaN          NaN           NaN  NaN
#
#   mailZipCode licensePrefix  licenseNumber   licenseExpirationDate  \
# 0       96067            RN       181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN       167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN      1622686.0  09/30/2021 12:00:00 AM
# 3         NaN           NaN            NaN                     NaN
# 4         NaN           NaN            NaN                     NaN
#
#   licenseStatusDescription
# 0                   Active
# 1                   Active
# 2                   Active
# 3                      NaN
# 4                      NaN

# %%
# Four - Remove Anesthesiologist Assistants because they do not require an RN sublicense and produce a compliance report
rn_status = rn_status[(rn_status["title"] == "CRNA")]
#rn_status.to_csv("report_nurse_compliance.csv", index=False, header=True)
rn_status.head()
# Out:
#   lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 0   Ackerman      Serena        Maija           97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R         1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira         1260  CRNA  10/23/2020 0:00
# 5     Bishop       Trent            M         1258  CRNA  11/13/2020 0:00
# 6  Boudreaux       David      Michael          551  CRNA  10/12/2010 0:00
#
#         matchName lastName_y firstName_y middleName_y          city  st  \
# 0  AckermanSerena   Ackerman      Serena        Maija  Mount Shasta  CA
# 1       AdamsChad      Adams        Chad            A      Longmont  CO
# 2    AhernCaitlin      Ahern     Caitlin        Moira     Englewood  CO
# 5     BishopTrent     Bishop       Trent            M       Durango  CO
# 6  BoudreauxDavid  Boudreaux       David      Michael   New Orleans  LA
#
#   mailZipCode licensePrefix  licenseNumber   licenseExpirationDate  \
# 0       96067            RN       181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN       167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN      1622686.0  09/30/2021 12:00:00 AM
# 5       81301            RN      1671331.0  09/30/2022 12:00:00 AM
# 6       70119            RN       197160.0  09/30/2022 12:00:00 AM
#
#   licenseStatusDescription
# 0                   Active
# 1                   Active
# 2                   Active
# 5                   Active
# 6                   Active

# %%
# Five - Produce a red flag list of anesthesia clinicians that do not have a required sublicense with "Active" status
rn_redflag = rn_status[(rn_status["licenseStatusDescription"] != "Active")]
#rn_redflag.to_csv("report_nurse_redflag.csv", index=False, header=True)
rn_redflag.head()
# Out:
#    lastName_x firstName_x middleName_x  employeeNum title         hireDate  \
# 20      Gates        Niki         Lynn          522  CRNA   6/19/2018 0:00
# 25   Jernigan      Amanda         Rhea          129  CRNA   3/14/2017 0:00
# 43   Lagrimas        Carl          NaN          775  CRNA   9/27/2019 0:00
# 44        Lam         Bao         Thai          370  CRNA    3/2/2018 0:00
# 77       Sims        John          NaN          112  CRNA  12/13/2016 0:00
#
#          matchName lastName_y firstName_y middleName_y       city   st  \
# 20       GatesNiki        NaN         NaN          NaN        NaN  NaN
# 25  JerniganAmanda   Jernigan      Amanda         Rhea  Nashville   TN
# 43    LagrimasCarl        NaN         NaN          NaN        NaN  NaN
# 44          LamBao        NaN         NaN          NaN        NaN  NaN
# 77        SimsJohn        NaN         NaN          NaN        NaN  NaN
#
#    mailZipCode licensePrefix  licenseNumber   licenseExpirationDate  \
# 20         NaN           NaN            NaN                     NaN
# 25       37205            RN       195510.0  03/14/2017 12:00:00 AM
# 43         NaN           NaN            NaN                     NaN
# 44         NaN           NaN            NaN                     NaN
# 77         NaN           NaN            NaN                     NaN
#
#    licenseStatusDescription
# 20                      NaN
# 25                  Expired
# 43                      NaN
# 44                      NaN
# 77                      NaN

# %% [markdown]
# Quality and issue checks ...

# %%
# wieser = anesthesia[(anesthesia["lastName"] == "Wieser")]
# wieser.head()

# %%
# wieser = employee[(employee["lastName"] == "Wieser")]
# wieser.head()

# %%
# wieser = nurse[(nurse["lastName"] == "Wieser")]
# wieser.head(100)

# %%
# gates = anesthesia[(anesthesia["lastName"] == "Gates")]
# gates.head()

# %%
# gates = employee[(employee["lastName"] == "Gates")]
# gates.head()

# %%
# gatesplus = nurse[(nurse["lastName"] == "Gates") & (nurse["firstName"] == "Nikki")]
# gatesplus.head(100)

# %%
# other = anesthesia[(anesthesia["lastName"] == "Fishell")]
# other.head()

# %% [markdown]
# # Extracting from new PGAdmin Database

# %%
# Creates a connection to the DB
engine = create_engine('postgresql://postgres:'+ passcode + '@localhost:5432/aEtlChallenge')
conn = engine.connect()

# %%
# Preview the anesthesia license data
al = pd.read_sql("SELECT * FROM anesthesialicense", conn)
al.head()
# Out:
#    lastname firstname middlename          city  st mailzipcode licenseprefix  \
# 0   Charles     James     Robert        Golden  CO       80401           APN
# 1     Stagg   Russell      Adair        Meeker  CO       81641         C-APN
# 2   Sampier    Nicole   Louise A         Tampa  FL       33602           APN
# 3  Trouskie   William    Leonard         Rifle  CO       81650           APN
# 4     Penix   Patrick  Alexander  Fort Collins  CO       80526           APN
#
#   subcategory licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 0        CRNA          3656  02/15/2002 12:00:00 AM  10/01/2019 12:00:00 AM
# 1      C-CRNA           211  06/18/2014 12:00:00 AM  06/18/2014 12:00:00 AM
# 2        CRNA        994392  01/03/2019 12:00:00 AM  10/01/2019 12:00:00 AM
# 3        CRNA         15066  03/02/2010 12:00:00 AM  10/01/2020 12:00:00 AM
# 4        CRNA        995315  01/27/2020 12:00:00 AM  10/01/2020 12:00:00 AM
#
#     licenseexpirationdate licensestatusdescription casenumber programaction  \
# 0  09/30/2021 12:00:00 AM                   Active       None          None
# 1  11/05/2014 12:00:00 AM                  Expired       None          None
# 2  09/30/2021 12:00:00 AM                   Active       None          None
# 3  09/30/2022 12:00:00 AM                   Active       None          None
# 4  09/30/2022 12:00:00 AM                   Active       None          None
#
#   disciplineeffectivedate disciplinecompletedate        matchname
# 0                    None                   None     CharlesJames
# 1                    None                   None     StaggRussell
# 2                    None                   None    SampierNicole
# 3                    None                   None  TrouskieWilliam
# 4                    None                   None     PenixPatrick

# %%
al.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2448 entries, 0 to 2447
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lastname                  2448 non-null   object
#  1   firstname                 2448 non-null   object
#  2   middlename                2200 non-null   object
#  3   city                      2448 non-null   object
#  4   st                        2448 non-null   object
#  5   mailzipcode               2447 non-null   object
#  6   licenseprefix             2448 non-null   object
#  7   subcategory               2310 non-null   object
#  8   licensenumber             2448 non-null   object
#  9   licensefirstissuedate     2448 non-null   object
#  10  licenselastreneweddate    2447 non-null   object
#  11  licenseexpirationdate     2448 non-null   object
#  12  licensestatusdescription  2448 non-null   object
#  13  casenumber                7 non-null      object
#  14  programaction             7 non-null      object
#  15  disciplineeffectivedate   7 non-null      object
#  16  disciplinecompletedate    1 non-null      object
#  17  matchname                 2448 non-null   object
# dtypes: object(18)
# memory usage: 344.4+ KB

# %%
# Preview the nurse license data
nl = pd.read_sql("SELECT * FROM nurselicense", conn)
nl.head()
# Out:
#    lastname firstname middlename              city  st mailzipcode  \
# 0  Saracino      Jodi        Kay            Arvada  CO       80004
# 1      Neal    Carmen    Darlene          Longview  TX       75608
# 2  Freeland    Judith         A.            BAILEY  CO       80421
# 3     Healy     Julie          E  Colorado Springs  CO       80920
# 4   Englade     Keith     Steven            Aurora  CO       80013
#
#   licenseprefix licensenumber   licenseexpirationdate  \
# 0            RN      103136.0  09/30/2021 12:00:00 AM
# 1            RN      181576.0  09/30/2015 12:00:00 AM
# 2            RN       92692.0  09/30/2005 12:00:00 AM
# 3            RN      130994.0  09/30/2021 12:00:00 AM
# 4            RN      205425.0  09/30/2022 12:00:00 AM
#
#   licensestatusdescription       matchname
# 0                   Active    SaracinoJodi
# 1                  Expired      NealCarmen
# 2                  Expired  FreelandJudith
# 3                   Active      HealyJulie
# 4                   Active    EngladeKeith

# %%
nl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196995 entries, 0 to 196994
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   lastname                  196994 non-null  object
#  1   firstname                 196993 non-null  object
#  2   middlename                180778 non-null  object
#  3   city                      196194 non-null  object
#  4   st                        194724 non-null  object
#  5   mailzipcode               195656 non-null  object
#  6   licenseprefix             196995 non-null  object
#  7   licensenumber             196991 non-null  object
#  8   licenseexpirationdate     196994 non-null  object
#  9   licensestatusdescription  196995 non-null  object
#  10  matchname                 196993 non-null  object
# dtypes: object(11)
# memory usage: 16.5+ MB

# %%
# Preview the employee_roster data
er = pd.read_sql("SELECT * FROM employeeroster", conn)
er.head()
# Out:
#    lastname firstname middlename employeenum title         hiredate  \
# 0  Ackerman    Serena      Maija          97  CRNA   3/16/2009 0:00
# 1     Adams      Chad          R        1049  CRNA    7/2/2018 0:00
# 2     Ahern   Caitlin      Moira        1260  CRNA  10/23/2020 0:00
# 3    Balyer       Ean       None         859    AA   3/20/2019 0:00
# 4  Barfield  Benjamin      James          67    AA    6/5/2013 0:00
#
#           matchname
# 0    AckermanSerena
# 1         AdamsChad
# 2      AhernCaitlin
# 3         BalyerEan
# 4  BarfieldBenjamin

# %%
er.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   lastname     79 non-null     object
#  1   firstname    79 non-null     object
#  2   middlename   67 non-null     object
#  3   employeenum  79 non-null     object
#  4   title        79 non-null     object
#  5   hiredate     79 non-null     object
#  6   matchname    79 non-null     object
# dtypes: object(7)
# memory usage: 4.4+ KB

# %% [markdown]
# # PGAdmin to Pandas Anesthesia License Management

# %%
# One - Merge the employee and anesthesia license status dataframes using a left join
pgastatus = pd.merge(er, al, on="matchname", how="left")
pgastatus.head(200)
# Out:
#     lastname_x  firstname_x middlename_x employeenum title         hiredate  \
# 0     Ackerman       Serena        Maija          97  CRNA   3/16/2009 0:00
# 1        Adams         Chad            R        1049  CRNA    7/2/2018 0:00
# 2        Ahern      Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 3        Ahern      Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 4       Balyer          Ean         None         859    AA   3/20/2019 0:00
# ..         ...          ...          ...         ...   ...              ...
# 96      Wieser  Christopher          Lee        1215  CRNA    5/5/2020 0:00
# 97       Woody     Patricia      McGuire         434  CRNA   1/23/2018 0:00
# 98       Woody     Patricia      McGuire         434  CRNA   1/23/2018 0:00
# 99      Wright        Henry       Wilson         824  CRNA    1/9/2007 0:00
# 100  Zimmerman       Philip         Ward         508  CRNA  10/16/2019 0:00
#
#              matchname lastname_y  firstname_y middlename_y  ... subcategory  \
# 0       AckermanSerena   Ackerman       Serena        Maija  ...        CRNA
# 1            AdamsChad      Adams         Chad            R  ...      C-CRNA
# 2         AhernCaitlin      Ahern      Caitlin        Moira  ...        CRNA
# 3         AhernCaitlin      Ahern      Caitlin        Moira  ...      C-CRNA
# 4            BalyerEan     Balyer          Ean         None  ...        None
# ..                 ...        ...          ...          ...  ...         ...
# 96   WieserChristopher     Wieser  Christopher          Lee  ...      C-CRNA
# 97       WoodyPatricia      Woody     Patricia      McGuire  ...        CRNA
# 98       WoodyPatricia      Woody     Patricia      McGuire  ...      C-CRNA
# 99         WrightHenry     Wright        Henry       Wilson  ...        CRNA
# 100    ZimmermanPhilip  Zimmerman       Philip         Ward  ...        CRNA
#
#     licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 0            6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1            1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 2          995962  10/23/2020 12:00:00 AM  10/23/2020 12:00:00 AM
# 3            2009  04/08/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 4             109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# ..            ...                     ...                     ...
# 96           2056  05/05/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 97         993651  01/23/2018 12:00:00 AM  10/01/2019 12:00:00 AM
# 98            784  06/05/2017 12:00:00 AM  06/05/2017 12:00:00 AM
# 99           5158  01/09/2007 12:00:00 AM  10/01/2020 12:00:00 AM
# 100        995110  10/16/2019 12:00:00 AM  10/16/2019 12:00:00 AM
#
#       licenseexpirationdate licensestatusdescription casenumber programaction  \
# 0    09/30/2021 12:00:00 AM                   Active       None          None
# 1    09/30/2022 12:00:00 AM                   Active       None          None
# 2    09/30/2021 12:00:00 AM                   Active       None          None
# 3    10/23/2020 12:00:00 AM                  Expired       None          None
# 4    01/31/2022 12:00:00 AM                   Active       None          None
# ..                      ...                      ...        ...           ...
# 96   09/30/2022 12:00:00 AM                   Active       None          None
# 97   09/30/2021 12:00:00 AM                   Active       None          None
# 98   01/23/2018 12:00:00 AM                  Expired       None          None
# 99   09/30/2022 12:00:00 AM                   Active       None          None
# 100  09/30/2021 12:00:00 AM                   Active       None          None
#
#     disciplineeffectivedate disciplinecompletedate
# 0                      None                   None
# 1                      None                   None
# 2                      None                   None
# 3                      None                   None
# 4                      None                   None
# ..                      ...                    ...
# 96                     None                   None
# 97                     None                   None
# 98                     None                   None
# 99                     None                   None
# 100                    None                   None
#
# [101 rows x 24 columns]

# %%
pgastatus['licenseexpirationdate'] = pd.to_datetime(pgastatus['licenseexpirationdate'], format = '%m%d%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-311-a5c8da902698> in <module>
# ----> 1 pgastatus['licenseexpirationdate'] = pd.to_datetime(pgastatus['licenseexpirationdate'], format = '%m%d%Y')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     797                 result = result.tz_localize(tz)
#     798     elif isinstance(arg, ABCSeries):
# --> 799         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     800         if not cache_array.empty:
#     801             result = arg.map(cache_array)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     168         unique_dates = unique(arg)
#     169         if len(unique_dates) < len(arg):
# --> 170             cache_dates = convert_listlike(unique_dates, format)
#     171             cache_array = Series(cache_dates, index=unique_dates)
#     172     return cache_array
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     452                 return DatetimeIndex._simple_new(dta, name=name)
#     453             except (ValueError, TypeError):
# --> 454                 raise e
#     455
#     456     if result is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     416                 try:
#     417                     result, timezones = array_strptime(
# --> 418                         arg, format, exact=exact, errors=errors
#     419                     )
#     420                     if "%Z" in format or "%z" in format:
#
# pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '09/30/2021 12:00:00 AM' does not match format '%m%d%Y' (match)

# %%
pgastatus.to_csv("check_pgastatus.csv", index=False, header=True)

# %%
pgastatus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lastname_x                101 non-null    object
#  1   firstname_x               101 non-null    object
#  2   middlename_x              84 non-null     object
#  3   employeenum               101 non-null    object
#  4   title                     101 non-null    object
#  5   hiredate                  101 non-null    object
#  6   matchname                 101 non-null    object
#  7   lastname_y                101 non-null    object
#  8   firstname_y               101 non-null    object
#  9   middlename_y              84 non-null     object
#  10  city                      101 non-null    object
#  11  st                        101 non-null    object
#  12  mailzipcode               101 non-null    object
#  13  licenseprefix             101 non-null    object
#  14  subcategory               94 non-null     object
#  15  licensenumber             101 non-null    object
#  16  licensefirstissuedate     101 non-null    object
#  17  licenselastreneweddate    101 non-null    object
#  18  licenseexpirationdate     101 non-null    object
#  19  licensestatusdescription  101 non-null    object
#  20  casenumber                0 non-null      object
#  21  programaction             0 non-null      object
#  22  disciplineeffectivedate   0 non-null      object
#  23  disciplinecompletedate    0 non-null      object
# dtypes: object(24)
# memory usage: 19.7+ KB

# %%
# TWo - Sort by matchName then licenseStatus, "Active" first
pgastatus.sort_values(by=['matchname', 'licensestatusdescription'], inplace=True)
pgastatus.head(200)
# Out:
#     lastname_x  firstname_x middlename_x employeenum title         hiredate  \
# 0     Ackerman       Serena        Maija          97  CRNA   3/16/2009 0:00
# 1        Adams         Chad            R        1049  CRNA    7/2/2018 0:00
# 2        Ahern      Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 3        Ahern      Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 4       Balyer          Ean         None         859    AA   3/20/2019 0:00
# ..         ...          ...          ...         ...   ...              ...
# 96      Wieser  Christopher          Lee        1215  CRNA    5/5/2020 0:00
# 97       Woody     Patricia      McGuire         434  CRNA   1/23/2018 0:00
# 98       Woody     Patricia      McGuire         434  CRNA   1/23/2018 0:00
# 99      Wright        Henry       Wilson         824  CRNA    1/9/2007 0:00
# 100  Zimmerman       Philip         Ward         508  CRNA  10/16/2019 0:00
#
#              matchname lastname_y  firstname_y middlename_y  ... subcategory  \
# 0       AckermanSerena   Ackerman       Serena        Maija  ...        CRNA
# 1            AdamsChad      Adams         Chad            R  ...      C-CRNA
# 2         AhernCaitlin      Ahern      Caitlin        Moira  ...        CRNA
# 3         AhernCaitlin      Ahern      Caitlin        Moira  ...      C-CRNA
# 4            BalyerEan     Balyer          Ean         None  ...        None
# ..                 ...        ...          ...          ...  ...         ...
# 96   WieserChristopher     Wieser  Christopher          Lee  ...      C-CRNA
# 97       WoodyPatricia      Woody     Patricia      McGuire  ...        CRNA
# 98       WoodyPatricia      Woody     Patricia      McGuire  ...      C-CRNA
# 99         WrightHenry     Wright        Henry       Wilson  ...        CRNA
# 100    ZimmermanPhilip  Zimmerman       Philip         Ward  ...        CRNA
#
#     licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 0            6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1            1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 2          995962  10/23/2020 12:00:00 AM  10/23/2020 12:00:00 AM
# 3            2009  04/08/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 4             109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# ..            ...                     ...                     ...
# 96           2056  05/05/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 97         993651  01/23/2018 12:00:00 AM  10/01/2019 12:00:00 AM
# 98            784  06/05/2017 12:00:00 AM  06/05/2017 12:00:00 AM
# 99           5158  01/09/2007 12:00:00 AM  10/01/2020 12:00:00 AM
# 100        995110  10/16/2019 12:00:00 AM  10/16/2019 12:00:00 AM
#
#       licenseexpirationdate licensestatusdescription casenumber programaction  \
# 0    09/30/2021 12:00:00 AM                   Active       None          None
# 1    09/30/2022 12:00:00 AM                   Active       None          None
# 2    09/30/2021 12:00:00 AM                   Active       None          None
# 3    10/23/2020 12:00:00 AM                  Expired       None          None
# 4    01/31/2022 12:00:00 AM                   Active       None          None
# ..                      ...                      ...        ...           ...
# 96   09/30/2022 12:00:00 AM                   Active       None          None
# 97   09/30/2021 12:00:00 AM                   Active       None          None
# 98   01/23/2018 12:00:00 AM                  Expired       None          None
# 99   09/30/2022 12:00:00 AM                   Active       None          None
# 100  09/30/2021 12:00:00 AM                   Active       None          None
#
#     disciplineeffectivedate disciplinecompletedate
# 0                      None                   None
# 1                      None                   None
# 2                      None                   None
# 3                      None                   None
# 4                      None                   None
# ..                      ...                    ...
# 96                     None                   None
# 97                     None                   None
# 98                     None                   None
# 99                     None                   None
# 100                    None                   None
#
# [101 rows x 24 columns]

# %%
pgastatus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lastname_x                101 non-null    object
#  1   firstname_x               101 non-null    object
#  2   middlename_x              84 non-null     object
#  3   employeenum               101 non-null    object
#  4   title                     101 non-null    object
#  5   hiredate                  101 non-null    object
#  6   matchname                 101 non-null    object
#  7   lastname_y                101 non-null    object
#  8   firstname_y               101 non-null    object
#  9   middlename_y              84 non-null     object
#  10  city                      101 non-null    object
#  11  st                        101 non-null    object
#  12  mailzipcode               101 non-null    object
#  13  licenseprefix             101 non-null    object
#  14  subcategory               94 non-null     object
#  15  licensenumber             101 non-null    object
#  16  licensefirstissuedate     101 non-null    object
#  17  licenselastreneweddate    101 non-null    object
#  18  licenseexpirationdate     101 non-null    object
#  19  licensestatusdescription  101 non-null    object
#  20  casenumber                0 non-null      object
#  21  programaction             0 non-null      object
#  22  disciplineeffectivedate   0 non-null      object
#  23  disciplinecompletedate    0 non-null      object
# dtypes: object(24)
# memory usage: 19.7+ KB

# %%
pgastatus.head()
# Out:
#   lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 0   Ackerman      Serena        Maija          97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R        1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 3      Ahern     Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 4     Balyer         Ean         None         859    AA   3/20/2019 0:00
#
#         matchname lastname_y firstname_y middlename_y  ... subcategory  \
# 0  AckermanSerena   Ackerman      Serena        Maija  ...        CRNA
# 1       AdamsChad      Adams        Chad            R  ...      C-CRNA
# 2    AhernCaitlin      Ahern     Caitlin        Moira  ...        CRNA
# 3    AhernCaitlin      Ahern     Caitlin        Moira  ...      C-CRNA
# 4       BalyerEan     Balyer         Ean         None  ...        None
#
#   licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 0          6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1          1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 2        995962  10/23/2020 12:00:00 AM  10/23/2020 12:00:00 AM
# 3          2009  04/08/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 4           109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
#
#     licenseexpirationdate licensestatusdescription casenumber programaction  \
# 0  09/30/2021 12:00:00 AM                   Active       None          None
# 1  09/30/2022 12:00:00 AM                   Active       None          None
# 2  09/30/2021 12:00:00 AM                   Active       None          None
# 3  10/23/2020 12:00:00 AM                  Expired       None          None
# 4  01/31/2022 12:00:00 AM                   Active       None          None
#
#   disciplineeffectivedate disciplinecompletedate
# 0                    None                   None
# 1                    None                   None
# 2                    None                   None
# 3                    None                   None
# 4                    None                   None
#
# [5 rows x 24 columns]

# %%
# Three Remove duplicates leaving the active license in the compliance reporting process if it exists
# Produce a compliance report that has status of all employees
pgastatus.drop_duplicates(subset ="matchname", keep = False, inplace = True) 
#pgastatus.to_csv("report_anesthesia_compliance.csv", index=False, header=True)
pgastatus.head(200)
# Out:
#       lastname_x  firstname_x middlename_x employeenum title         hiredate  \
# 0       Ackerman       Serena        Maija          97  CRNA   3/16/2009 0:00
# 1          Adams         Chad            R        1049  CRNA    7/2/2018 0:00
# 4         Balyer          Ean         None         859    AA   3/20/2019 0:00
# 5       Barfield     Benjamin        James          67    AA    6/5/2013 0:00
# 8      Boudreaux        David      Michael         551  CRNA  10/12/2010 0:00
# 9          Bramm     Jonathan        David         926    AA  10/21/2013 0:00
# 10        Brunin         Tara      Suzanne         168  CRNA    8/9/2011 0:00
# 13     Carpenter         Leah          Sue         513  CRNA   3/30/2007 0:00
# 14      Christie      Timothy       Robert         139  CRNA  12/16/2010 0:00
# 17       Croshal       Andrea         Lynn         906    AA   5/27/2016 0:00
# 20        De Lay         Mary            S         662  CRNA   3/10/2010 0:00
# 23     Engelmann          Amy        Lynne         499  CRNA   10/4/2011 0:00
# 24      Engstrom       Jaclyn        Marie         591  CRNA   10/8/2019 0:00
# 31    Heringhaus       Nathan            S        1041  CRNA   4/15/2015 0:00
# 32    Hermsmeier      Michael       Archie         617  CRNA   2/16/2011 0:00
# 37       Johnson        Laura        Adele        1194  CRNA    8/7/2019 0:00
# 41     Karpowitz      Bradley            R         280  CRNA   3/30/2020 0:00
# 42       Knowles         Phil       Ramsey         895  CRNA   6/13/2014 0:00
# 43      Lagrimas         Carl         None         775  CRNA   9/27/2019 0:00
# 44           Lam          Bao         Thai         370  CRNA    3/2/2018 0:00
# 45           Lee      Michael         John         904  CRNA   10/7/2013 0:00
# 46        Lester      Candace         None        1022    AA   5/31/2019 0:00
# 47         Lewis      Barbara         Lynn        1189  CRNA    8/3/1995 0:00
# 48      Macaulay    Katharine          San         362  CRNA   3/27/1995 0:00
# 49      Mahannah         Wren     Winnicki         435  CRNA   1/10/2020 0:00
# 52   McChristian     Kathleen         Mary         341  CRNA   12/5/2017 0:00
# 53         McKay        Kelly         None         887  CRNA   8/25/2015 0:00
# 54    McNaughton       Stacey          Ann         619  CRNA   7/22/2009 0:00
# 55        Miller        Jacob      Matthew        1113  CRNA   6/18/2018 0:00
# 56       Oliveti       Joseph        Bruno         897  CRNA   10/4/2012 0:00
# 57       Pacione     Nicholas         John         235  CRNA   12/4/2015 0:00
# 58       Parslow      Janelle    Ann Duray         404  CRNA    1/8/2008 0:00
# 63       Racette        Aimee        Marie         663  CRNA  11/18/2003 0:00
# 64      Redelius       Monica         None         911    AA    7/3/2013 0:00
# 67        Romero       Thomas       Andrew         936  CRNA   1/17/2017 0:00
# 68     Rosenblum        Carla          Sue         500  CRNA   1/12/2007 0:00
# 71      Sauthoff       Andrew            M         877  CRNA   2/27/2018 0:00
# 72      Schimmel      Carolyn        Marie        1207  CRNA  12/30/2002 0:00
# 73         Selby       Amanda      Lucinda         200  CRNA  10/26/2010 0:00
# 74        Semmes     Michelle        Leigh         839  CRNA   3/14/2019 0:00
# 75         Shank     Claudine       Dale A         107  CRNA    7/7/2004 0:00
# 76       Sherman       Lauren      Roberts         724  CRNA   1/25/2012 0:00
# 77          Sims         John         None         112  CRNA  12/13/2016 0:00
# 78       Skinner      Zachary         None         697  CRNA   1/23/2020 0:00
# 80         Smith       Audrey            M        1252  CRNA   4/15/2004 0:00
# 81         Smith    Catherine           Vu        1255  CRNA  11/24/2020 0:00
# 79         Smith         Ryan        David         652    AA   2/12/2016 0:00
# 82         Starr          Ann       Warner         969  CRNA  12/13/2018 0:00
# 83        Taylor       Andrea          Lyn        1108  CRNA   4/17/2000 0:00
# 84     Tegtmeyer    Katherine       Yvonne        1224  CRNA   2/17/2015 0:00
# 85         Thiel         Sara      Kirsten        1039  CRNA   2/11/2015 0:00
# 86       Tilbury    Christine       Nicole         213  CRNA    7/6/2010 0:00
# 87         Tobin        David            A          40  CRNA  12/27/2016 0:00
# 88       Vallier      Jonelle        Lynae         382  CRNA    1/6/2012 0:00
# 89          Vial       Leslie       Elaine         334  CRNA   8/29/2018 0:00
# 94       Wehrman          Amy            M         929  CRNA   3/27/2003 0:00
# 95     Wesselink        Darin         Drew         208  CRNA   1/13/2020 0:00
# 96        Wieser  Christopher          Lee        1215  CRNA    5/5/2020 0:00
# 99        Wright        Henry       Wilson         824  CRNA    1/9/2007 0:00
# 100    Zimmerman       Philip         Ward         508  CRNA  10/16/2019 0:00
#
#                matchname   lastname_y  firstname_y middlename_y  ...  \
# 0         AckermanSerena     Ackerman       Serena        Maija  ...
# 1              AdamsChad        Adams         Chad            R  ...
# 4              BalyerEan       Balyer          Ean         None  ...
# 5       BarfieldBenjamin     Barfield     Benjamin        James  ...
# 8         BoudreauxDavid    Boudreaux        David      Michael  ...
# 9          BrammJonathan        Bramm     Jonathan        David  ...
# 10            BruninTara       Brunin         Tara      Suzanne  ...
# 13         CarpenterLeah    Carpenter         Leah          Sue  ...
# 14       ChristieTimothy     Christie      Timothy       Robert  ...
# 17         CroshalAndrea      Croshal       Andrea         Lynn  ...
# 20            De LayMary       De Lay         Mary            S  ...
# 23          EngelmannAmy    Engelmann          Amy        Lynne  ...
# 24        EngstromJaclyn     Engstrom       Jaclyn        Marie  ...
# 31      HeringhausNathan   Heringhaus       Nathan            S  ...
# 32     HermsmeierMichael   Hermsmeier      Michael       Archie  ...
# 37          JohnsonLaura      Johnson        Laura        Adele  ...
# 41      KarpowitzBradley    Karpowitz      Bradley            R  ...
# 42           KnowlesPhil      Knowles         Phil       Ramsey  ...
# 43          LagrimasCarl     Lagrimas         Carl         None  ...
# 44                LamBao          Lam          Bao         Thai  ...
# 45            LeeMichael          Lee      Michael         John  ...
# 46         LesterCandace       Lester      Candace         None  ...
# 47          LewisBarbara        Lewis      Barbara         Lynn  ...
# 48     MacaulayKatharine     Macaulay    Katharine          San  ...
# 49          MahannahWren     Mahannah         Wren     Winnicki  ...
# 52   McChristianKathleen  McChristian     Kathleen         Mary  ...
# 53            McKayKelly        McKay        Kelly         None  ...
# 54      McNaughtonStacey   McNaughton       Stacey          Ann  ...
# 55           MillerJacob       Miller        Jacob      Matthew  ...
# 56         OlivetiJoseph      Oliveti       Joseph        Bruno  ...
# 57       PacioneNicholas      Pacione     Nicholas         John  ...
# 58        ParslowJanelle      Parslow      Janelle    Ann Duray  ...
# 63          RacetteAimee      Racette        Aimee        Marie  ...
# 64        RedeliusMonica     Redelius       Monica         None  ...
# 67          RomeroThomas       Romero       Thomas       Andrew  ...
# 68        RosenblumCarla    Rosenblum        Carla          Sue  ...
# 71        SauthoffAndrew     Sauthoff       Andrew            M  ...
# 72       SchimmelCarolyn     Schimmel      Carolyn        Marie  ...
# 73           SelbyAmanda        Selby       Amanda      Lucinda  ...
# 74        SemmesMichelle       Semmes     Michelle        Leigh  ...
# 75         ShankClaudine        Shank     Claudine       Dale A  ...
# 76         ShermanLauren      Sherman       Lauren      Roberts  ...
# 77              SimsJohn         Sims         John         None  ...
# 78        SkinnerZachary      Skinner      Zachary         None  ...
# 80           SmithAudrey        Smith       Audrey            M  ...
# 81        SmithCatherine        Smith    Catherine           Vu  ...
# 79             SmithRyan        Smith         Ryan        David  ...
# 82              StarrAnn        Starr          Ann       Warner  ...
# 83          TaylorAndrea       Taylor       Andrea          Lyn  ...
# 84    TegtmeyerKatherine    Tegtmeyer    Katherine       Yvonne  ...
# 85             ThielSara        Thiel         Sara      Kirsten  ...
# 86      TilburyChristine      Tilbury    Christine       Nicole  ...
# 87            TobinDavid        Tobin        David            A  ...
# 88        VallierJonelle      Vallier      Jonelle        Lynae  ...
# 89            VialLeslie         Vial       Leslie       Elaine  ...
# 94            WehrmanAmy      Wehrman          Amy            M  ...
# 95        WesselinkDarin    Wesselink        Darin         Drew  ...
# 96     WieserChristopher       Wieser  Christopher          Lee  ...
# 99           WrightHenry       Wright        Henry       Wilson  ...
# 100      ZimmermanPhilip    Zimmerman       Philip         Ward  ...
#
#     subcategory licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 0          CRNA          6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1        C-CRNA          1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 4          None           109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# 5          None            10  06/05/2013 12:00:00 AM  02/01/2020 12:00:00 AM
# 8          CRNA        100010  10/12/2010 12:00:00 AM  10/01/2020 12:00:00 AM
# 9          None            24  10/21/2013 12:00:00 AM  02/01/2020 12:00:00 AM
# 10         CRNA        100049  08/09/2011 12:00:00 AM  10/01/2019 12:00:00 AM
# 13         CRNA          5252  03/30/2007 12:00:00 AM  10/01/2019 12:00:00 AM
# 14         CRNA        100021  12/16/2010 12:00:00 AM  10/01/2020 12:00:00 AM
# 17         None            61  05/27/2016 12:00:00 AM  02/01/2020 12:00:00 AM
# 20       C-CRNA         25019  03/10/2010 12:00:00 AM  10/01/2020 12:00:00 AM
# 23         CRNA        100055  10/04/2011 12:00:00 AM  10/01/2019 12:00:00 AM
# 24         CRNA        995091  10/08/2019 12:00:00 AM  10/08/2019 12:00:00 AM
# 31         CRNA        991732  04/15/2015 12:00:00 AM  10/01/2019 12:00:00 AM
# 32         CRNA        100031  02/16/2011 12:00:00 AM  10/01/2019 12:00:00 AM
# 37       C-CRNA          1656  08/07/2019 12:00:00 AM  08/07/2019 12:00:00 AM
# 41         CRNA        995469  03/30/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 42         CRNA        991221  06/13/2014 12:00:00 AM  10/01/2020 12:00:00 AM
# 43       C-CRNA          1752  09/27/2019 12:00:00 AM  09/27/2019 12:00:00 AM
# 44       C-CRNA           995  03/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 45         CRNA        990934  10/07/2013 12:00:00 AM  10/01/2019 12:00:00 AM
# 46         None           112  05/31/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# 47         CRNA          1610  08/03/1995 12:00:00 AM  10/01/2019 12:00:00 AM
# 48         CRNA           265  03/27/1995 12:00:00 AM  10/01/2020 12:00:00 AM
# 49         CRNA        995278  01/10/2020 12:00:00 AM  01/10/2020 12:00:00 AM
# 52         CRNA        993601  12/05/2017 12:00:00 AM  10/01/2019 12:00:00 AM
# 53         CRNA        991932  08/25/2015 12:00:00 AM  10/01/2019 12:00:00 AM
# 54         CRNA         15012  07/22/2009 12:00:00 AM  10/01/2019 12:00:00 AM
# 55       C-CRNA          1120  06/18/2018 12:00:00 AM  06/18/2018 12:00:00 AM
# 56         CRNA        990517  10/04/2012 12:00:00 AM  10/01/2020 12:00:00 AM
# 57         CRNA        992116  12/04/2015 12:00:00 AM  10/01/2019 12:00:00 AM
# 58         CRNA          5539  01/08/2008 12:00:00 AM  10/01/2020 12:00:00 AM
# 63         CRNA          4217  11/18/2003 12:00:00 AM  10/01/2020 12:00:00 AM
# 64         None            18  07/03/2013 12:00:00 AM  02/01/2020 12:00:00 AM
# 67         CRNA        992887  01/17/2017 12:00:00 AM  10/01/2018 12:00:00 AM
# 68         CRNA          5161  01/12/2007 12:00:00 AM  10/01/2019 12:00:00 AM
# 71         CRNA        993713  02/27/2018 12:00:00 AM  10/01/2019 12:00:00 AM
# 72         CRNA          3924  12/30/2002 12:00:00 AM  10/01/2020 12:00:00 AM
# 73         CRNA        100014  10/26/2010 12:00:00 AM  10/01/2018 12:00:00 AM
# 74         CRNA        994547  03/14/2019 12:00:00 AM  10/01/2019 12:00:00 AM
# 75         CRNA          4377  07/07/2004 12:00:00 AM  10/01/2020 12:00:00 AM
# 76         CRNA        100087  01/25/2012 12:00:00 AM  10/01/2019 12:00:00 AM
# 77       C-CRNA           661  12/13/2016 12:00:00 AM  10/01/2020 12:00:00 AM
# 78       C-CRNA          1882  01/23/2020 12:00:00 AM  01/23/2020 12:00:00 AM
# 80         CRNA          4301  04/15/2004 12:00:00 AM  10/01/2019 12:00:00 AM
# 81       C-CRNA          1082  05/21/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 79         None            55  02/12/2016 12:00:00 AM  02/01/2020 12:00:00 AM
# 82       C-CRNA          1327  12/13/2018 12:00:00 AM  12/13/2018 12:00:00 AM
# 83         CRNA          3040  04/17/2000 12:00:00 AM  10/01/2020 12:00:00 AM
# 84         CRNA        991641  02/17/2015 12:00:00 AM  10/01/2019 12:00:00 AM
# 85         CRNA        991626  02/11/2015 12:00:00 AM  10/01/2019 12:00:00 AM
# 86         CRNA         15082  07/06/2010 12:00:00 AM  10/01/2019 12:00:00 AM
# 87         CRNA        992853  12/27/2016 12:00:00 AM  10/01/2020 12:00:00 AM
# 88         CRNA        100081  01/06/2012 12:00:00 AM  10/01/2019 12:00:00 AM
# 89       C-CRNA          1183  08/29/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 94         CRNA          4005  03/27/2003 12:00:00 AM  10/01/2020 12:00:00 AM
# 95         CRNA        995282  01/13/2020 12:00:00 AM  01/13/2020 12:00:00 AM
# 96       C-CRNA          2056  05/05/2020 12:00:00 AM  10/01/2020 12:00:00 AM
# 99         CRNA          5158  01/09/2007 12:00:00 AM  10/01/2020 12:00:00 AM
# 100        CRNA        995110  10/16/2019 12:00:00 AM  10/16/2019 12:00:00 AM
#
#       licenseexpirationdate licensestatusdescription casenumber programaction  \
# 0    09/30/2021 12:00:00 AM                   Active       None          None
# 1    09/30/2022 12:00:00 AM                   Active       None          None
# 4    01/31/2022 12:00:00 AM                   Active       None          None
# 5    01/31/2022 12:00:00 AM                   Active       None          None
# 8    09/30/2022 12:00:00 AM                   Active       None          None
# 9    01/31/2022 12:00:00 AM                   Active       None          None
# 10   09/30/2021 12:00:00 AM                   Active       None          None
# 13   09/30/2021 12:00:00 AM                   Active       None          None
# 14   09/30/2022 12:00:00 AM                   Active       None          None
# 17   01/31/2022 12:00:00 AM                   Active       None          None
# 20   09/30/2022 12:00:00 AM                   Active       None          None
# 23   09/30/2021 12:00:00 AM                   Active       None          None
# 24   09/30/2021 12:00:00 AM                   Active       None          None
# 31   09/30/2021 12:00:00 AM                   Active       None          None
# 32   09/30/2021 12:00:00 AM                   Active       None          None
# 37   09/30/2021 12:00:00 AM                   Active       None          None
# 41   09/30/2022 12:00:00 AM                   Active       None          None
# 42   09/30/2022 12:00:00 AM                   Active       None          None
# 43   09/30/2021 12:00:00 AM                   Active       None          None
# 44   09/30/2022 12:00:00 AM                   Active       None          None
# 45   09/30/2021 12:00:00 AM                   Active       None          None
# 46   01/31/2022 12:00:00 AM                   Active       None          None
# 47   09/30/2021 12:00:00 AM                   Active       None          None
# 48   09/30/2022 12:00:00 AM                   Active       None          None
# 49   09/30/2021 12:00:00 AM                   Active       None          None
# 52   09/30/2021 12:00:00 AM                   Active       None          None
# 53   09/30/2021 12:00:00 AM                   Active       None          None
# 54   09/30/2021 12:00:00 AM                   Active       None          None
# 55   09/30/2020 12:00:00 AM                   Active       None          None
# 56   09/30/2022 12:00:00 AM                   Active       None          None
# 57   09/30/2021 12:00:00 AM                   Active       None          None
# 58   09/30/2022 12:00:00 AM                   Active       None          None
# 63   09/30/2022 12:00:00 AM                   Active       None          None
# 64   01/31/2022 12:00:00 AM                   Active       None          None
# 67   09/30/2020 12:00:00 AM                   Active       None          None
# 68   09/30/2021 12:00:00 AM                   Active       None          None
# 71   09/30/2021 12:00:00 AM                   Active       None          None
# 72   09/30/2022 12:00:00 AM                   Active       None          None
# 73   09/30/2020 12:00:00 AM                   Active       None          None
# 74   09/30/2021 12:00:00 AM                   Active       None          None
# 75   09/30/2022 12:00:00 AM                   Active       None          None
# 76   09/30/2021 12:00:00 AM                   Active       None          None
# 77   09/30/2022 12:00:00 AM                   Active       None          None
# 78   09/30/2020 12:00:00 AM                   Active       None          None
# 80   09/30/2021 12:00:00 AM                   Active       None          None
# 81   11/24/2020 12:00:00 AM                  Expired       None          None
# 79   01/31/2022 12:00:00 AM                   Active       None          None
# 82   09/30/2020 12:00:00 AM                   Active       None          None
# 83   09/30/2022 12:00:00 AM                   Active       None          None
# 84   09/30/2021 12:00:00 AM                   Active       None          None
# 85   09/30/2021 12:00:00 AM                   Active       None          None
# 86   09/30/2021 12:00:00 AM                   Active       None          None
# 87   09/30/2022 12:00:00 AM                   Active       None          None
# 88   09/30/2021 12:00:00 AM                   Active       None          None
# 89   09/30/2022 12:00:00 AM                   Active       None          None
# 94   09/30/2022 12:00:00 AM                   Active       None          None
# 95   09/30/2021 12:00:00 AM                   Active       None          None
# 96   09/30/2022 12:00:00 AM                   Active       None          None
# 99   09/30/2022 12:00:00 AM                   Active       None          None
# 100  09/30/2021 12:00:00 AM                   Active       None          None
#
#     disciplineeffectivedate disciplinecompletedate
# 0                      None                   None
# 1                      None                   None
# 4                      None                   None
# 5                      None                   None
# 8                      None                   None
# 9                      None                   None
# 10                     None                   None
# 13                     None                   None
# 14                     None                   None
# 17                     None                   None
# 20                     None                   None
# 23                     None                   None
# 24                     None                   None
# 31                     None                   None
# 32                     None                   None
# 37                     None                   None
# 41                     None                   None
# 42                     None                   None
# 43                     None                   None
# 44                     None                   None
# 45                     None                   None
# 46                     None                   None
# 47                     None                   None
# 48                     None                   None
# 49                     None                   None
# 52                     None                   None
# 53                     None                   None
# 54                     None                   None
# 55                     None                   None
# 56                     None                   None
# 57                     None                   None
# 58                     None                   None
# 63                     None                   None
# 64                     None                   None
# 67                     None                   None
# 68                     None                   None
# 71                     None                   None
# 72                     None                   None
# 73                     None                   None
# 74                     None                   None
# 75                     None                   None
# 76                     None                   None
# 77                     None                   None
# 78                     None                   None
# 80                     None                   None
# 81                     None                   None
# 79                     None                   None
# 82                     None                   None
# 83                     None                   None
# 84                     None                   None
# 85                     None                   None
# 86                     None                   None
# 87                     None                   None
# 88                     None                   None
# 89                     None                   None
# 94                     None                   None
# 95                     None                   None
# 96                     None                   None
# 99                     None                   None
# 100                    None                   None
#
# [60 rows x 24 columns]

# %%
# Three-B rename compliance report
pgastatus2 = pgastatus.rename(columns={"lastname_x": "Last_Name", "firstname_x": "First_Name","middlename_x": "Middle_Name" ,"employeenum": "Employee_Number","title": "Title","hiredate": "Hire_Date","licensenumber": "License_Number","licenseexpirationdate": "Expiration_Date","licensestatusdescription": "License_Status"})
pgastatus2.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 0   Ackerman     Serena       Maija              97  CRNA   3/16/2009 0:00
# 1      Adams       Chad           R            1049  CRNA    7/2/2018 0:00
# 4     Balyer        Ean        None             859    AA   3/20/2019 0:00
# 5   Barfield   Benjamin       James              67    AA    6/5/2013 0:00
# 8  Boudreaux      David     Michael             551  CRNA  10/12/2010 0:00
#
#           matchname lastname_y firstname_y middlename_y  ... subcategory  \
# 0    AckermanSerena   Ackerman      Serena        Maija  ...        CRNA
# 1         AdamsChad      Adams        Chad            R  ...      C-CRNA
# 4         BalyerEan     Balyer         Ean         None  ...        None
# 5  BarfieldBenjamin   Barfield    Benjamin        James  ...        None
# 8    BoudreauxDavid  Boudreaux       David      Michael  ...        CRNA
#
#   License_Number   licensefirstissuedate  licenselastreneweddate  \
# 0           6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1           1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 4            109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# 5             10  06/05/2013 12:00:00 AM  02/01/2020 12:00:00 AM
# 8         100010  10/12/2010 12:00:00 AM  10/01/2020 12:00:00 AM
#
#           Expiration_Date License_Status casenumber programaction  \
# 0  09/30/2021 12:00:00 AM         Active       None          None
# 1  09/30/2022 12:00:00 AM         Active       None          None
# 4  01/31/2022 12:00:00 AM         Active       None          None
# 5  01/31/2022 12:00:00 AM         Active       None          None
# 8  09/30/2022 12:00:00 AM         Active       None          None
#
#   disciplineeffectivedate disciplinecompletedate
# 0                    None                   None
# 1                    None                   None
# 4                    None                   None
# 5                    None                   None
# 8                    None                   None
#
# [5 rows x 24 columns]

# %%
# Three-C Narrow the report to the needed information for consumption
pgastatus3 = pgastatus2[["Last_Name", "First_Name", "Middle_Name", "Employee_Number", "Title", "Hire_Date", "License_Number", "Expiration_Date", "License_Status"]]
pgastatus3.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 0   Ackerman     Serena       Maija              97  CRNA   3/16/2009 0:00
# 1      Adams       Chad           R            1049  CRNA    7/2/2018 0:00
# 4     Balyer        Ean        None             859    AA   3/20/2019 0:00
# 5   Barfield   Benjamin       James              67    AA    6/5/2013 0:00
# 8  Boudreaux      David     Michael             551  CRNA  10/12/2010 0:00
#
#   License_Number         Expiration_Date License_Status
# 0           6026  09/30/2021 12:00:00 AM         Active
# 1           1154  09/30/2022 12:00:00 AM         Active
# 4            109  01/31/2022 12:00:00 AM         Active
# 5             10  01/31/2022 12:00:00 AM         Active
# 8         100010  09/30/2022 12:00:00 AM         Active

# %%
# Three-D - Save to csv file for report consumption
pgastatus3.to_csv("report_anesthesia_compliance.csv", index=False, header=True)

# %%
# Four-A Produce a red flag report of out of compliance anesthesia clinicians
pgredflag = pgastatus[(pgastatus["licensestatusdescription"] == "Expired")]
pgredflag.head()
# Out:
#    lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 81      Smith   Catherine           Vu        1255  CRNA  11/24/2020 0:00
#
#          matchname lastname_y firstname_y middlename_y  ... subcategory  \
# 81  SmithCatherine      Smith   Catherine           Vu  ...      C-CRNA
#
#    licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 81          1082  05/21/2018 12:00:00 AM  10/01/2020 12:00:00 AM
#
#      licenseexpirationdate licensestatusdescription casenumber programaction  \
# 81  11/24/2020 12:00:00 AM                  Expired       None          None
#
#    disciplineeffectivedate disciplinecompletedate
# 81                    None                   None
#
# [1 rows x 24 columns]

# %%
# Four-B rename redflag report
pgredflag2 = pgredflag.rename(columns={"lastname_x": "Last_Name", "firstname_x": "First_Name","middlename_x": "Middle_Name" ,"employeenum": "Employee_Number","title": "Title","hiredate": "Hire_Date","licensenumber": "License_Number","licenseexpirationdate": "Expiration_Date","licensestatusdescription": "License_Status"})
pgredflag2.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 81     Smith  Catherine          Vu            1255  CRNA  11/24/2020 0:00
#
#          matchname lastname_y firstname_y middlename_y  ... subcategory  \
# 81  SmithCatherine      Smith   Catherine           Vu  ...      C-CRNA
#
#    License_Number   licensefirstissuedate  licenselastreneweddate  \
# 81           1082  05/21/2018 12:00:00 AM  10/01/2020 12:00:00 AM
#
#            Expiration_Date License_Status casenumber programaction  \
# 81  11/24/2020 12:00:00 AM        Expired       None          None
#
#    disciplineeffectivedate disciplinecompletedate
# 81                    None                   None
#
# [1 rows x 24 columns]

# %%
# Four-C Narrow the report to the needed information for consumption
pgredflag3 = pgredflag2[["Last_Name", "First_Name", "Middle_Name", "Employee_Number", "Title", "Hire_Date", "License_Number", "Expiration_Date", "License_Status"]]
pgredflag3.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 81     Smith  Catherine          Vu            1255  CRNA  11/24/2020 0:00
#
#    License_Number         Expiration_Date License_Status
# 81           1082  11/24/2020 12:00:00 AM        Expired

# %%
# Five - Save to csv file for report consumption
pgredflag3.to_csv("report_anesthesia_redflag.csv", index=False, header=True)

# %% [markdown]
# # PGAdmin to Pandas - Registered Nurse Sub-license Management

# %%
# One - Merge the employee and registered nurse license status table using a left join
pgrn_status = pd.merge(er, nl, on="matchname", how="left")
pgrn_status.head()
# Out:
#   lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 0   Ackerman      Serena        Maija          97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R        1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 3     Balyer         Ean         None         859    AA   3/20/2019 0:00
# 4   Barfield    Benjamin        James          67    AA    6/5/2013 0:00
#
#           matchname lastname_y firstname_y middlename_y          city   st  \
# 0    AckermanSerena   Ackerman      Serena        Maija  Mount Shasta   CA
# 1         AdamsChad      Adams        Chad            A      Longmont   CO
# 2      AhernCaitlin      Ahern     Caitlin        Moira     Englewood   CO
# 3         BalyerEan        NaN         NaN          NaN           NaN  NaN
# 4  BarfieldBenjamin        NaN         NaN          NaN           NaN  NaN
#
#   mailzipcode licenseprefix licensenumber   licenseexpirationdate  \
# 0       96067            RN      181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN      167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN     1622686.0  09/30/2021 12:00:00 AM
# 3         NaN           NaN           NaN                     NaN
# 4         NaN           NaN           NaN                     NaN
#
#   licensestatusdescription
# 0                   Active
# 1                   Active
# 2                   Active
# 3                      NaN
# 4                      NaN

# %%
# Two - Sort by matchName then licenseStatus, "Active" first
pgrn_status.sort_values(by=['matchname', 'licensestatusdescription'], inplace=True)
pgrn_status.head()
# Out:
#   lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 0   Ackerman      Serena        Maija          97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R        1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 3     Balyer         Ean         None         859    AA   3/20/2019 0:00
# 4   Barfield    Benjamin        James          67    AA    6/5/2013 0:00
#
#           matchname lastname_y firstname_y middlename_y          city   st  \
# 0    AckermanSerena   Ackerman      Serena        Maija  Mount Shasta   CA
# 1         AdamsChad      Adams        Chad            A      Longmont   CO
# 2      AhernCaitlin      Ahern     Caitlin        Moira     Englewood   CO
# 3         BalyerEan        NaN         NaN          NaN           NaN  NaN
# 4  BarfieldBenjamin        NaN         NaN          NaN           NaN  NaN
#
#   mailzipcode licenseprefix licensenumber   licenseexpirationdate  \
# 0       96067            RN      181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN      167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN     1622686.0  09/30/2021 12:00:00 AM
# 3         NaN           NaN           NaN                     NaN
# 4         NaN           NaN           NaN                     NaN
#
#   licensestatusdescription
# 0                   Active
# 1                   Active
# 2                   Active
# 3                      NaN
# 4                      NaN

# %%
# Three - Remove duplicates leaving the "Active" status if true
pgrn_status.drop_duplicates(subset ="matchname", keep = False, inplace = True) 
pgrn_status.head()
# Out:
#   lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 0   Ackerman      Serena        Maija          97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R        1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 3     Balyer         Ean         None         859    AA   3/20/2019 0:00
# 4   Barfield    Benjamin        James          67    AA    6/5/2013 0:00
#
#           matchname lastname_y firstname_y middlename_y          city   st  \
# 0    AckermanSerena   Ackerman      Serena        Maija  Mount Shasta   CA
# 1         AdamsChad      Adams        Chad            A      Longmont   CO
# 2      AhernCaitlin      Ahern     Caitlin        Moira     Englewood   CO
# 3         BalyerEan        NaN         NaN          NaN           NaN  NaN
# 4  BarfieldBenjamin        NaN         NaN          NaN           NaN  NaN
#
#   mailzipcode licenseprefix licensenumber   licenseexpirationdate  \
# 0       96067            RN      181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN      167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN     1622686.0  09/30/2021 12:00:00 AM
# 3         NaN           NaN           NaN                     NaN
# 4         NaN           NaN           NaN                     NaN
#
#   licensestatusdescription
# 0                   Active
# 1                   Active
# 2                   Active
# 3                      NaN
# 4                      NaN

# %%
# Four - Remove Anesthesiologist Assistants because they do not require an RN sublicense 
# Produce a compliance report with statsu of all CRNA's sub-license status
pgrn_status = pgrn_status[(pgrn_status["title"] == "CRNA")]
#pgrn_status.to_csv("report_rnsublicense_compliance.csv", index=False, header=True)
pgrn_status.head()
# Out:
#   lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 0   Ackerman      Serena        Maija          97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R        1049  CRNA    7/2/2018 0:00
# 2      Ahern     Caitlin        Moira        1260  CRNA  10/23/2020 0:00
# 5     Bishop       Trent            M        1258  CRNA  11/13/2020 0:00
# 6  Boudreaux       David      Michael         551  CRNA  10/12/2010 0:00
#
#         matchname lastname_y firstname_y middlename_y          city  st  \
# 0  AckermanSerena   Ackerman      Serena        Maija  Mount Shasta  CA
# 1       AdamsChad      Adams        Chad            A      Longmont  CO
# 2    AhernCaitlin      Ahern     Caitlin        Moira     Englewood  CO
# 5     BishopTrent     Bishop       Trent            M       Durango  CO
# 6  BoudreauxDavid  Boudreaux       David      Michael   New Orleans  LA
#
#   mailzipcode licenseprefix licensenumber   licenseexpirationdate  \
# 0       96067            RN      181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN      167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN     1622686.0  09/30/2021 12:00:00 AM
# 5       81301            RN     1671331.0  09/30/2022 12:00:00 AM
# 6       70119            RN      197160.0  09/30/2022 12:00:00 AM
#
#   licensestatusdescription
# 0                   Active
# 1                   Active
# 2                   Active
# 5                   Active
# 6                   Active

# %%
# Four-B rename redflag report
pgrn_status2 = pgrn_status.rename(columns={"lastname_x": "Last_Name", "firstname_x": "First_Name","middlename_x": "Middle_Name" ,"employeenum": "Employee_Number","title": "Title","hiredate": "Hire_Date","licensenumber": "License_Number","licenseexpirationdate": "Expiration_Date","licensestatusdescription": "License_Status"})
pgrn_status2.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 0   Ackerman     Serena       Maija              97  CRNA   3/16/2009 0:00
# 1      Adams       Chad           R            1049  CRNA    7/2/2018 0:00
# 2      Ahern    Caitlin       Moira            1260  CRNA  10/23/2020 0:00
# 5     Bishop      Trent           M            1258  CRNA  11/13/2020 0:00
# 6  Boudreaux      David     Michael             551  CRNA  10/12/2010 0:00
#
#         matchname lastname_y firstname_y middlename_y          city  st  \
# 0  AckermanSerena   Ackerman      Serena        Maija  Mount Shasta  CA
# 1       AdamsChad      Adams        Chad            A      Longmont  CO
# 2    AhernCaitlin      Ahern     Caitlin        Moira     Englewood  CO
# 5     BishopTrent     Bishop       Trent            M       Durango  CO
# 6  BoudreauxDavid  Boudreaux       David      Michael   New Orleans  LA
#
#   mailzipcode licenseprefix License_Number         Expiration_Date  \
# 0       96067            RN       181740.0  09/30/2021 12:00:00 AM
# 1       80503            RN       167534.0  09/30/2021 12:00:00 AM
# 2       80112            RN      1622686.0  09/30/2021 12:00:00 AM
# 5       81301            RN      1671331.0  09/30/2022 12:00:00 AM
# 6       70119            RN       197160.0  09/30/2022 12:00:00 AM
#
#   License_Status
# 0         Active
# 1         Active
# 2         Active
# 5         Active
# 6         Active

# %%
# Four-C Narrow the report to the needed information for consumption
pgrn_status3 = pgrn_status2[["Last_Name", "First_Name", "Middle_Name", "Employee_Number", "Title", "Hire_Date", "License_Number", "Expiration_Date", "License_Status"]]
pgrn_status3.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 0   Ackerman     Serena       Maija              97  CRNA   3/16/2009 0:00
# 1      Adams       Chad           R            1049  CRNA    7/2/2018 0:00
# 2      Ahern    Caitlin       Moira            1260  CRNA  10/23/2020 0:00
# 5     Bishop      Trent           M            1258  CRNA  11/13/2020 0:00
# 6  Boudreaux      David     Michael             551  CRNA  10/12/2010 0:00
#
#   License_Number         Expiration_Date License_Status
# 0       181740.0  09/30/2021 12:00:00 AM         Active
# 1       167534.0  09/30/2021 12:00:00 AM         Active
# 2      1622686.0  09/30/2021 12:00:00 AM         Active
# 5      1671331.0  09/30/2022 12:00:00 AM         Active
# 6       197160.0  09/30/2022 12:00:00 AM         Active

# %%
# Four-D - Save to csv file for report consumption
pgrn_status3.to_csv("report_rnsublicense_compliance.csv", index=False, header=True)

# %%
# Five-A - Produce a red flag list of anesthesia clinicians that do not have a required sublicense with "Active" status 
pgrn_redflag = pgrn_status[(pgrn_status["licensestatusdescription"] != "Active")]
#pgrn_redflag.to_csv("report_pgnurse_redflag.csv", index=False, header=True)
pgrn_redflag.head()
# Out:
#    lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 20      Gates        Niki         Lynn         522  CRNA   6/19/2018 0:00
# 25   Jernigan      Amanda         Rhea         129  CRNA   3/14/2017 0:00
# 43   Lagrimas        Carl         None         775  CRNA   9/27/2019 0:00
# 44        Lam         Bao         Thai         370  CRNA    3/2/2018 0:00
# 77       Sims        John         None         112  CRNA  12/13/2016 0:00
#
#          matchname lastname_y firstname_y middlename_y       city   st  \
# 20       GatesNiki        NaN         NaN          NaN        NaN  NaN
# 25  JerniganAmanda   Jernigan      Amanda         Rhea  Nashville   TN
# 43    LagrimasCarl        NaN         NaN          NaN        NaN  NaN
# 44          LamBao        NaN         NaN          NaN        NaN  NaN
# 77        SimsJohn        NaN         NaN          NaN        NaN  NaN
#
#    mailzipcode licenseprefix licensenumber   licenseexpirationdate  \
# 20         NaN           NaN           NaN                     NaN
# 25       37205            RN      195510.0  03/14/2017 12:00:00 AM
# 43         NaN           NaN           NaN                     NaN
# 44         NaN           NaN           NaN                     NaN
# 77         NaN           NaN           NaN                     NaN
#
#    licensestatusdescription
# 20                      NaN
# 25                  Expired
# 43                      NaN
# 44                      NaN
# 77                      NaN

# %%
# Five-B rename redflag report
pgrn_redflag2 = pgrn_redflag.rename(columns={"lastname_x": "Last_Name", "firstname_x": "First_Name","middlename_x": "Middle_Name" ,"employeenum": "Employee_Number","title": "Title","hiredate": "Hire_Date","licensenumber": "License_Number","licenseexpirationdate": "Expiration_Date","licensestatusdescription": "License_Status"})
pgrn_redflag2.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 20     Gates       Niki        Lynn             522  CRNA   6/19/2018 0:00
# 25  Jernigan     Amanda        Rhea             129  CRNA   3/14/2017 0:00
# 43  Lagrimas       Carl        None             775  CRNA   9/27/2019 0:00
# 44       Lam        Bao        Thai             370  CRNA    3/2/2018 0:00
# 77      Sims       John        None             112  CRNA  12/13/2016 0:00
#
#          matchname lastname_y firstname_y middlename_y       city   st  \
# 20       GatesNiki        NaN         NaN          NaN        NaN  NaN
# 25  JerniganAmanda   Jernigan      Amanda         Rhea  Nashville   TN
# 43    LagrimasCarl        NaN         NaN          NaN        NaN  NaN
# 44          LamBao        NaN         NaN          NaN        NaN  NaN
# 77        SimsJohn        NaN         NaN          NaN        NaN  NaN
#
#    mailzipcode licenseprefix License_Number         Expiration_Date  \
# 20         NaN           NaN            NaN                     NaN
# 25       37205            RN       195510.0  03/14/2017 12:00:00 AM
# 43         NaN           NaN            NaN                     NaN
# 44         NaN           NaN            NaN                     NaN
# 77         NaN           NaN            NaN                     NaN
#
#    License_Status
# 20            NaN
# 25        Expired
# 43            NaN
# 44            NaN
# 77            NaN

# %%
# Five-C Narrow the report to the needed information for consumption
pgrn_redflag3 = pgrn_redflag2[["Last_Name", "First_Name", "Middle_Name", "Employee_Number", "Title", "Hire_Date", "License_Number", "Expiration_Date", "License_Status"]]
pgrn_redflag3.head()
# Out:
#    Last_Name First_Name Middle_Name Employee_Number Title        Hire_Date  \
# 20     Gates       Niki        Lynn             522  CRNA   6/19/2018 0:00
# 25  Jernigan     Amanda        Rhea             129  CRNA   3/14/2017 0:00
# 43  Lagrimas       Carl        None             775  CRNA   9/27/2019 0:00
# 44       Lam        Bao        Thai             370  CRNA    3/2/2018 0:00
# 77      Sims       John        None             112  CRNA  12/13/2016 0:00
#
#    License_Number         Expiration_Date License_Status
# 20            NaN                     NaN            NaN
# 25       195510.0  03/14/2017 12:00:00 AM        Expired
# 43            NaN                     NaN            NaN
# 44            NaN                     NaN            NaN
# 77            NaN                     NaN            NaN

# %%
# Six - Save to csv file for report consumption
pgrn_redflag3.to_csv("report_rnsublicense_redflag.csv", index=False, header=True)

# %% [markdown]
# # PGAdmin to Pandas - Anesthesia Cautionary Report

# %%
# Cautionary Report of License Due in next 90 days
#pgastatus90 = pgastatus(pgastatus[(licenseexpirationdate) < '2021-03-30']
#pgastatus90 = pgastatus[(pgastatus["licenseexpirationdate"] < "2021-03-30")]
pgastatus90 = pgastatus[(pgastatus["licenseexpirationdate"] < "3/30/2021")]
pgastatus90.to_csv("report_anesthesia_yellowflag.csv", index=False, header=True)
pgastatus90.head()
# Out:
#   lastname_x firstname_x middlename_x employeenum title         hiredate  \
# 0   Ackerman      Serena        Maija          97  CRNA   3/16/2009 0:00
# 1      Adams        Chad            R        1049  CRNA    7/2/2018 0:00
# 4     Balyer         Ean         None         859    AA   3/20/2019 0:00
# 5   Barfield    Benjamin        James          67    AA    6/5/2013 0:00
# 8  Boudreaux       David      Michael         551  CRNA  10/12/2010 0:00
#
#           matchname lastname_y firstname_y middlename_y  ... subcategory  \
# 0    AckermanSerena   Ackerman      Serena        Maija  ...        CRNA
# 1         AdamsChad      Adams        Chad            R  ...      C-CRNA
# 4         BalyerEan     Balyer         Ean         None  ...        None
# 5  BarfieldBenjamin   Barfield    Benjamin        James  ...        None
# 8    BoudreauxDavid  Boudreaux       David      Michael  ...        CRNA
#
#   licensenumber   licensefirstissuedate  licenselastreneweddate  \
# 0          6026  03/16/2009 12:00:00 AM  09/06/2019 12:00:00 AM
# 1          1154  07/02/2018 12:00:00 AM  10/01/2020 12:00:00 AM
# 4           109  03/20/2019 12:00:00 AM  02/01/2020 12:00:00 AM
# 5            10  06/05/2013 12:00:00 AM  02/01/2020 12:00:00 AM
# 8        100010  10/12/2010 12:00:00 AM  10/01/2020 12:00:00 AM
#
#     licenseexpirationdate licensestatusdescription casenumber programaction  \
# 0  09/30/2021 12:00:00 AM                   Active       None          None
# 1  09/30/2022 12:00:00 AM                   Active       None          None
# 4  01/31/2022 12:00:00 AM                   Active       None          None
# 5  01/31/2022 12:00:00 AM                   Active       None          None
# 8  09/30/2022 12:00:00 AM                   Active       None          None
#
#   disciplineeffectivedate disciplinecompletedate
# 0                    None                   None
# 1                    None                   None
# 4                    None                   None
# 5                    None                   None
# 8                    None                   None
#
# [5 rows x 24 columns]

# %%
# Rodgers ETL-Project End
