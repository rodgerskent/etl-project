# %%
# This notebook converts the main license file from the State of Colorado into two license files
# One specific to anesthesia license information
# A second with all registered nurses for license reconcilation management

# %%
# Dependencies
import pandas as pd

# %%
df=pd.read_csv('license_central.csv')
df.head()
# Out:
#     lastName firstName middleName suffix entityName         city state  \
# 0  Lonnquist      Eryn     Amelia    NaN        NaN       Denver    CO
# 1      James    Joseph        NaN    NaN        NaN       Golden    CO
# 2   Lenthall    Sandra          R    NaN        NaN     Morrison    CO
# 3      Baker   Allison          W    NaN        NaN      Kingman    AZ
# 4    Hubbach      John    Wallace    NaN        NaN  Castle Rock    CO
#
#   mailZipCode licensePrefix subCategory  ... licenseStatusDescription  \
# 0       80206            TL         NaN  ...                  Expired
# 1       80401           APE         NaN  ...                  Expired
# 2       80465           COS         NaN  ...                   Active
# 3       86409            PE         NaN  ...                   Active
# 4       80104           DEN         NaN  ...                  Expired
#
#            specialty title          degrees caseNumber programAction  \
# ...

# %%
# Consolidated list of anesthesiologist Assistants, Colorado CRNA's and Compact CRNA's
anesthesia = df[(df["subCategory"] == "CRNA") + (df["subCategory"] == "C-CRNA") + (df["licensePrefix"] == "ANT")][(df["licensePrefix"] != "MSAPN")][(df["licensePrefix"] != "MSRXN")]
anesthesia.to_csv("license_anesthesia.csv", index=False, header=True)
anesthesia.head()
# Out:
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py:201: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       lastName firstName middleName suffix entityName          city state  \
# 400    Charles     James     Robert    NaN        NaN        Golden    CO
# 552      Stagg   Russell      Adair    NaN        NaN        Meeker    CO
# 835    Sampier    Nicole   Louise A    NaN        NaN         Tampa    FL
# 1646  Trouskie   William    Leonard     JR        NaN         Rifle    CO
# 2359     Penix   Patrick  Alexander    NaN        NaN  Fort Collins    CO
#
#      mailZipCode licensePrefix subCategory  ... licenseStatusDescription  \
# ...

# %%
anesthesia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2448 entries, 400 to 1231681
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   lastName                     2448 non-null   object
#  1   firstName                    2448 non-null   object
#  2   middleName                   2200 non-null   object
#  3   suffix                       44 non-null     object
#  4   entityName                   0 non-null      object
#  5   city                         2448 non-null   object
#  6   state                        2448 non-null   object
#  7   mailZipCode                  2447 non-null   object
#  8   licensePrefix                2448 non-null   object
#  9   subCategory                  2310 non-null   object
#  10  licenseNumber                2448 non-null   object
#  11  licenseFirstIssueDate        2448 non-null   object
# ...

# %%
# Complete listing of licenses RN's (registered nurses) in State of Colorado. 
# The CRNA's are duplicative on this list and the anesthesia list because they must maintain two licenses
regnurse = df[(df["licensePrefix"] == "RN")]
regnurse.to_csv("license_regnurse.csv", index=False, header=True)
regnurse.head()
# Out:
#     lastName firstName middleName suffix entityName              city state  \
# 6   Saracino      Jodi        Kay    NaN        NaN            Arvada    CO
# 7       Neal    Carmen    Darlene    NaN        NaN          Longview    TX
# 8   Freeland    Judith         A.    NaN        NaN            BAILEY    CO
# 11     Healy     Julie          E    NaN        NaN  Colorado Springs    CO
# 18   Englade     Keith     Steven    NaN        NaN            Aurora    CO
#
#    mailZipCode licensePrefix subCategory  ... licenseStatusDescription  \
# 6        80004            RN         NaN  ...                   Active
# 7        75608            RN         NaN  ...                  Expired
# 8        80421            RN         NaN  ...                  Expired
# 11       80920            RN         NaN  ...                   Active
# 18       80013            RN         NaN  ...                   Active
#
#    specialty title                           degrees caseNumber programAction  \
# ...

# %%
regnurse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196995 entries, 6 to 1231867
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   lastName                     196994 non-null  object
#  1   firstName                    196993 non-null  object
#  2   middleName                   180778 non-null  object
#  3   suffix                       615 non-null     object
#  4   entityName                   1 non-null       object
#  5   city                         196194 non-null  object
#  6   state                        194724 non-null  object
#  7   mailZipCode                  195656 non-null  object
#  8   licensePrefix                196995 non-null  object
#  9   subCategory                  0 non-null       object
#  10  licenseNumber                196991 non-null  object
#  11  licenseFirstIssueDate        196994 non-null  object
# ...

# %%
employees=pd.read_csv('employee_roster.csv')
employees.head()
# Out:
#    lastName firstName middleName  employeeNum              city state  \
# 0     Tobin     David          A           40     winston salem    NC
# 1  Barfield  Benjamin      James           67            Denver    CO
# 2  Ackerman    Serena      Maija           97      Mount Shasta    CA
# 3     Shank  Claudine     Dale A          107  Colorado Springs    CO
# 4      Sims      John        NaN          112       Little Rock    AR
#
#    mailZipCode title         hireDate  projectIndicator
# 0        27103  CRNA  12/27/2016 0:00                 1
# 1        80238    AA    6/5/2013 0:00                 1
# 2        96067  CRNA   3/16/2009 0:00                 1
# 3        80921  CRNA    7/7/2004 0:00                 1
# 4        72210  CRNA  12/13/2016 0:00                 1

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   lastName          80 non-null     object
#  1   firstName         80 non-null     object
#  2   middleName        67 non-null     object
#  3   employeeNum       80 non-null     int64
#  4   city              80 non-null     object
#  5   state             80 non-null     object
#  6   mailZipCode       80 non-null     int64
#  7   title             80 non-null     object
#  8   hireDate          80 non-null     object
#  9   projectIndicator  80 non-null     int64
# dtypes: int64(3), object(7)
# memory usage: 6.4+ KB

# %%
crosscheck = df[(df["lastName"] == "Melliar-Smith")]
crosscheck.to_csv("xcrosscheck.csv", index=False, header=True)
crosscheck.head()
# Out:
#              lastName firstName middleName suffix entityName    city state  \
# 43661   Melliar-Smith     Karen          B    NaN        NaN  Denver    CO
# 480896  Melliar-Smith     Karen          B    NaN        NaN  Denver    CO
#
#        mailZipCode licensePrefix subCategory  ... licenseStatusDescription  \
# 43661        80209           APN        CRNA  ...                   Active
# 480896       80209            RN         NaN  ...                   Active
#
#        specialty title                           degrees caseNumber  \
# 43661        NaN   NaN  ~Bachelors of Science in Nursing        NaN
# 480896       NaN   NaN  ~Bachelors of Science in Nursing        NaN
#
#        programAction  disciplineEffectiveDate disciplineCompleteDate  \
# 43661            NaN                      NaN                    NaN
# 480896           NaN                      NaN                    NaN
#
#                                       linkToVerifyLicense  \
# ...

# %%
# Query to help support a fruitful ficticious employee roster
rosterstarter = df[(df["subCategory"] == "CRNA") + (df["subCategory"] == "C-CRNA") + (df["licensePrefix"] == "ANT")][(df["licensePrefix"] != "MSAPN")][(df["licensePrefix"] != "MSRXN")][(df["licenseStatusDescription"] == "Expired")]
rosterstarter.to_csv("x_rosterstarter.csv", index=False, header=True)
rosterstarter.head()
# Out:
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py:201: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       lastName firstName   middleName suffix entityName          city state  \
# 552      Stagg   Russell        Adair    NaN        NaN        Meeker    CO
# 3010  Skidmore      Mark       Verlyn    NaN        NaN        Golden    CO
# 5121      Bray   William        Olney    NaN        NaN  Skipperville    AL
# 6190      Bray    Summer  Remembrance    NaN        NaN     Brookline    MA
# 6316   Geraets    Ronald       Howard    NaN        NaN  Fort Collins    CO
#
# ...

# %%
# Query to help support a fruitful ficticious employee roster
employeestarter = df[(df["subCategory"] == "CRNA") + (df["subCategory"] == "C-CRNA") + (df["licensePrefix"] == "ANT")][(df["licensePrefix"] != "MSAPN")][(df["licensePrefix"] != "MSRXN")][(df["licenseStatusDescription"] == "Active")]
employeestarter.to_csv("x_employeestarter.csv", index=False, header=True)
employeestarter.head()
# Out:
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py:201: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       lastName firstName middleName suffix entityName          city state  \
# 400    Charles     James     Robert    NaN        NaN        Golden    CO
# 835    Sampier    Nicole   Louise A    NaN        NaN         Tampa    FL
# 1646  Trouskie   William    Leonard     JR        NaN         Rifle    CO
# 2359     Penix   Patrick  Alexander    NaN        NaN  Fort Collins    CO
# 3818  Peterson    Steven       Kyle    NaN        NaN    Ft Collins    CO
#
# ...

# %%
martic = df[(df["lastName"] == "Martic")]
martic.head()
# Out:
#        lastName firstName middleName suffix entityName              city  \
# 157506   Martic      Ivan        NaN    NaN        NaN  Colorado Springs
# 916672   Martic      Ivan        NaN    NaN        NaN  Colorado Springs
# 947914   Martic      Ivan        NaN    NaN        NaN  Colorado Springs
#
#        state mailZipCode licensePrefix subCategory  ...  \
# 157506    CO       80910            RN         NaN  ...
# 916672    CO       80910           APN        CRNA  ...
# 947914    CO       80910         C-APN      C-CRNA  ...
#
#        licenseStatusDescription specialty title  \
# 157506                   Active       NaN   NaN
# 916672                   Active       NaN   NaN
# 947914                  Expired       NaN   NaN
#
#                                  degrees caseNumber programAction  \
# 157506  ~Bachelors of Science in Nursing        NaN           NaN
# 916672  ~Bachelors of Science in Nursing        NaN           NaN
# ...
